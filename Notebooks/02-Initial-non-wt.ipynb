# %% [markdown]
# # 02- Analysis of Head-to-Head LDC Fitness Competitions
# ##  Mutant vs mutant (non WT) competitions
#
# Click here to go back to the <a href="0-Index.ipynb"> "Table of Contents" </a>

# %% [markdown]
# ### Load Data

# %%
# Importing intrinsic libraries:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statannot import add_stat_annotation
import os 
os.chdir("..")

# %%
# Loading Pandas DataFrame:
data2 = pd.read_csv("Datasets/initial-mutant-mutant.csv")

# Lets subset the data into our CLC and LDC results
data2_ldc = data2[data2.condition == "LDC"]
data2_clc = data2[data2.condition == "CLC"]

# %% [markdown]
# # Lets now look at the competitions of KO mutant vs KO mutant from LDC conditions:
#
# ### Make a box plot
# Plot the individual replicate data points and group the timepoints together for each strain.
# First start the the data from competitions flasks incubated in 12-12 LDC (~150 uE)

# %%
# Set variables you want to plot
plt.figure(figsize=(10,5))

x = "strain"
y = "percent-mutant"
order=["day 0", "day 2", "day 6"]

swarmplot2ldc = sns.swarmplot(data=data2_ldc, x=x, y=y, hue = "day", dodge=True, 
               palette=sns.color_palette(['black', 'black', 'black']), hue_order=order)

boxplot2ldc = sns.boxplot(data=data2_ldc, x=x, y=y, hue="day", hue_order=order,
                       palette=sns.color_palette(['seagreen', 'coral', 'royalblue']))

# control x and y limits
boxplot2ldc.set(ylim=(0, 1))
swarmplot2ldc.set(ylim=(0, 1))

boxplot2ldc.axes.set_title("LDC",fontsize=20)
boxplot2ldc.set_xlabel("Percent of Strain 1",fontsize=20)
boxplot2ldc.set_ylabel("Day",fontsize=20)
boxplot2ldc.tick_params(labelsize=20)

stat_1936_0644 = add_stat_annotation(boxplot2ldc, data=data2_ldc, x=x, y=y, hue="day",
                    boxPairList=[(("_1936-_0644", "day 0"), ("_1936-_0644", "day 2")),
                                 (("_1936-_0644", "day 2"), ("_1936-_0644", "day 6")),
                                 (("_1936-_0644", "day 0"), ("_1936-_0644", "day 6"))],
                    test='t-test_ind', textFormat='star', loc='outside', verbose=2, fontsize='x-large')

stat_2453_0644 = add_stat_annotation(boxplot2ldc, data=data2_ldc, x=x, y=y, hue="day",
                    boxPairList=[(("_2453-_0644", "day 0"), ("_2453-_0644", "day 2")),
                                 (("_2453-_0644", "day 2"), ("_2453-_0644", "day 6")),
                                 (("_2453-_0644", "day 0"), ("_2453-_0644", "day 6"))],
                    test='t-test_ind', textFormat='star', loc='outside', verbose=2, fontsize='x-large')

# Fix the legand
# Get the handles and labels. 
handles, labels = boxplot2ldc.get_legend_handles_labels()
# When creating the legend, only use the first two elements to effectively remove the last two.
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize='x-large', title_fontsize='40')
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# _1936-_0644_day 0 v.s. _1936-_0644_day 2: t-test independent samples, P_val=7.532e-01 stat=3.368e-01
# _1936-_0644_day 2 v.s. _1936-_0644_day 6: t-test independent samples, P_val=3.307e-03 stat=6.268e+00
# _1936-_0644_day 0 v.s. _1936-_0644_day 6: t-test independent samples, P_val=4.218e-04 stat=1.077e+01
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# _2453-_0644_day 0 v.s. _2453-_0644_day 2: t-test independent samples, P_val=7.505e-01 stat=3.406e-01
# _2453-_0644_day 2 v.s. _2453-_0644_day 6: t-test independent samples, P_val=3.200e-01 stat=-1.134e+00
# _2453-_0644_day 0 v.s. _2453-_0644_day 6: t-test independent samples, P_val=3.549e-01 stat=-1.045e+00

# %% [markdown]
# ### Make it a bar plot

# %%
# Set variables you want to plot
plt.figure(figsize=(10,5))

x = "strain"
y = "percent-mutant"
order=["day 0", "day 2", "day 6"]

swarmplot2ldc = sns.swarmplot(data=data2_ldc, x=x, y=y, hue = "day", dodge=True, 
               palette=sns.color_palette(['black', 'black', 'black']), hue_order=order)

barplot2ldc = sns.barplot(data=data2_ldc, x=x, y=y, hue="day", hue_order=order,
                       palette=sns.color_palette(['seagreen', 'coral', 'royalblue']))

# control x and y limits
barplot2ldc.set(ylim=(0, 1))
swarmplot2ldc.set(ylim=(0, 1))
barplot2ldc.axes.set_title("LDC",fontsize=20)
barplot2ldc.set_xlabel("Percent of Strain 1",fontsize=20)
barplot2ldc.set_ylabel("Day",fontsize=20)
barplot2ldc.tick_params(labelsize=20)

stat_1936_0644 = add_stat_annotation(barplot2ldc, data=data2_ldc, x=x, y=y, hue="day",
                    boxPairList=[(("_1936-_0644", "day 0"), ("_1936-_0644", "day 2")),
                                 (("_1936-_0644", "day 2"), ("_1936-_0644", "day 6")),
                                 (("_1936-_0644", "day 0"), ("_1936-_0644", "day 6"))],
                    test='t-test_ind', textFormat='star', loc='outside', verbose=2, fontsize='x-large')

stat_2453_0644 = add_stat_annotation(barplot2ldc, data=data2_ldc, x=x, y=y, hue="day",
                    boxPairList=[(("_2453-_0644", "day 0"), ("_2453-_0644", "day 2")),
                                 (("_2453-_0644", "day 2"), ("_2453-_0644", "day 6")),
                                 (("_2453-_0644", "day 0"), ("_2453-_0644", "day 6"))],
                    test='t-test_ind', textFormat='star', loc='outside', verbose=2, fontsize='x-large')



plt.legend(loc='upper left', bbox_to_anchor=(1.03, 1))
# Fix the legand
# Get the handles and labels. 
handles, labels = boxplot2ldc.get_legend_handles_labels()
# When creating the legend, only use the first two elements to effectively remove the last two.
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., )
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# _1936-_0644_day 0 v.s. _1936-_0644_day 2: t-test independent samples, P_val=7.532e-01 stat=3.368e-01
# _1936-_0644_day 2 v.s. _1936-_0644_day 6: t-test independent samples, P_val=3.307e-03 stat=6.268e+00
# _1936-_0644_day 0 v.s. _1936-_0644_day 6: t-test independent samples, P_val=4.218e-04 stat=1.077e+01
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# _2453-_0644_day 0 v.s. _2453-_0644_day 2: t-test independent samples, P_val=7.505e-01 stat=3.406e-01
# _2453-_0644_day 2 v.s. _2453-_0644_day 6: t-test independent samples, P_val=3.200e-01 stat=-1.134e+00
# _2453-_0644_day 0 v.s. _2453-_0644_day 6: t-test independent samples, P_val=3.549e-01 stat=-1.045e+00

# %% [markdown]
# ### From this, we conclude that our control competition of the clockless 7942_1936 vs the cikA KO 7942_0644 indicated that cikA out competed the clockless strain missing kaiABC.
#
# ### The strain 7942_2453 (encoding pilM) has a LDC fitness value of +1.7 and 7942_0644 (encoding cikA) has a score of 1.4. While we did see an average increase in the strain with the higher fitness score, this was not statistically signifigant due to the variation we observed between biological replicates.

# %% [markdown]
# # CLC Conditions

# %%
# Set variables you want to plot
plt.figure(figsize=(10,5))

x = "strain"
y = "percent-mutant"
order=["day 0", "day 2", "day 6"]

swarmplot2clc = sns.swarmplot(data=data2_clc, x=x, y=y, hue = "day", dodge=True, 
               palette=sns.color_palette(['black', 'black', 'black']), hue_order=order)

boxplot2clc = sns.boxplot(data=data2_clc, x=x, y=y, hue="day", hue_order=order,
                       palette=sns.color_palette(['seagreen', 'coral', 'royalblue']))

# control x and y limits
boxplot2clc.set(ylim=(0, 1))
swarmplot2clc.set(ylim=(0, 1))

boxplot2clc.axes.set_title("CLC",fontsize=20)
boxplot2clc.set_xlabel("Percent of Strain 1",fontsize=20)
boxplot2clc.set_ylabel("Day",fontsize=20)
boxplot2clc.tick_params(labelsize=20)

stat_1936_0644 = add_stat_annotation(boxplot2clc, data=data2_clc, x=x, y=y, hue="day",
                    boxPairList=[(("_1936-_0644", "day 0"), ("_1936-_0644", "day 2")),
                                 (("_1936-_0644", "day 2"), ("_1936-_0644", "day 6")),
                                 (("_1936-_0644", "day 0"), ("_1936-_0644", "day 6"))],
                    test='t-test_ind', textFormat='star', loc='outside', verbose=2, fontsize='x-large')

stat_2453_0644 = add_stat_annotation(boxplot2clc, data=data2_clc, x=x, y=y, hue="day",
                    boxPairList=[(("_2453-_0644", "day 0"), ("_2453-_0644", "day 2")),
                                 (("_2453-_0644", "day 2"), ("_2453-_0644", "day 6")),
                                 (("_2453-_0644", "day 0"), ("_2453-_0644", "day 6"))],
                    test='t-test_ind', textFormat='star', loc='outside', verbose=2, fontsize='x-large')

# Fix the legand
# Get the handles and labels. 
handles, labels = boxplot2clc.get_legend_handles_labels()
# When creating the legend, only use the first two elements to effectively remove the last two.
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize='x-large', title_fontsize='40')
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# _1936-_0644_day 0 v.s. _1936-_0644_day 2: t-test independent samples, P_val=2.964e-01 stat=1.200e+00
# _1936-_0644_day 2 v.s. _1936-_0644_day 6: t-test independent samples, P_val=9.430e-01 stat=-7.614e-02
# _1936-_0644_day 0 v.s. _1936-_0644_day 6: t-test independent samples, P_val=1.051e-01 stat=2.087e+00
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# _2453-_0644_day 0 v.s. _2453-_0644_day 2: t-test independent samples, P_val=1.110e-01 stat=2.039e+00
# _2453-_0644_day 2 v.s. _2453-_0644_day 6: t-test independent samples, P_val=3.774e-02 stat=-3.058e+00
# _2453-_0644_day 0 v.s. _2453-_0644_day 6: t-test independent samples, P_val=7.757e-01 stat=-3.048e-01

# %%
# Set variables you want to plot
plt.figure(figsize=(10,5))

x = "strain"
y = "percent-mutant"
order=["day 0", "day 2", "day 6"]


swarmplot2clc = sns.swarmplot(data=data2_clc, x=x, y=y, hue = "day", dodge=True, 
               palette=sns.color_palette(['black', 'black', 'black']), hue_order=order)

barplot2clc = sns.barplot(data=data2_clc, x=x, y=y, hue="day", hue_order=order,
                       palette=sns.color_palette(['seagreen', 'coral', 'royalblue']))

# control x and y limits
barplot2clc.set(ylim=(0, 1))
swarmplot2clc.set(ylim=(0, 1))
barplot2clc.axes.set_title("CLC",fontsize=20)
barplot2clc.set_xlabel("Percent of Strain 1",fontsize=20)
barplot2clc.set_ylabel("Day",fontsize=20)
barplot2clc.tick_params(labelsize=20)

stat_1936_0644 = add_stat_annotation(barplot2clc, data=data2_clc, x=x, y=y, hue="day",
                    boxPairList=[(("_1936-_0644", "day 0"), ("_1936-_0644", "day 2")),
                                 (("_1936-_0644", "day 2"), ("_1936-_0644", "day 6")),
                                 (("_1936-_0644", "day 0"), ("_1936-_0644", "day 6"))],
                    test='t-test_ind', textFormat='star', loc='outside', verbose=2, fontsize='x-large')

stat_2453_0644 = add_stat_annotation(barplot2clc, data=data2_clc, x=x, y=y, hue="day",
                    boxPairList=[(("_2453-_0644", "day 0"), ("_2453-_0644", "day 2")),
                                 (("_2453-_0644", "day 2"), ("_2453-_0644", "day 6")),
                                 (("_2453-_0644", "day 0"), ("_2453-_0644", "day 6"))],
                    test='t-test_ind', textFormat='star', loc='outside', verbose=2, fontsize='x-large')



plt.legend(loc='upper left', bbox_to_anchor=(1.03, 1))
# Fix the legand
# Get the handles and labels. 
handles, labels = boxplot2ldc.get_legend_handles_labels()
# When creating the legend, only use the first two elements to effectively remove the last two.
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize='x-large', title_fontsize='40')
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# _1936-_0644_day 0 v.s. _1936-_0644_day 2: t-test independent samples, P_val=2.964e-01 stat=1.200e+00
# _1936-_0644_day 2 v.s. _1936-_0644_day 6: t-test independent samples, P_val=9.430e-01 stat=-7.614e-02
# _1936-_0644_day 0 v.s. _1936-_0644_day 6: t-test independent samples, P_val=1.051e-01 stat=2.087e+00
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# _2453-_0644_day 0 v.s. _2453-_0644_day 2: t-test independent samples, P_val=1.110e-01 stat=2.039e+00
# _2453-_0644_day 2 v.s. _2453-_0644_day 6: t-test independent samples, P_val=3.774e-02 stat=-3.058e+00
# _2453-_0644_day 0 v.s. _2453-_0644_day 6: t-test independent samples, P_val=7.757e-01 stat=-3.048e-01

# %% [markdown]
# ## Click here to continue to <a href="03-Strain0863-highl-lowl.ipynb"> "Follow up experiemnts performed on the strain 7942_0863" </a>
#
# ### Or if you want to print the figures:

# %%
barplot2ldc = barplot2ldc.get_figure()
barplot2clc = barplot2clc.get_figure()

barplot2ldc.savefig('Figures/barplot2ldc.png', dpi=400, bbox_inches="tight")
barplot2clc.savefig('Figures/barplot2clc.png', dpi=400, bbox_inches="tight")
