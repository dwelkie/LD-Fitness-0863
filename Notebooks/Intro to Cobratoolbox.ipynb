% %% [markdown]
% # A Brief COBRA TOOLBOX 101

% %% [markdown]
% <img src="figures/cobralogo.jpg" width="700">

% %% [markdown]
% ## From microbe to model
% A constraint-based metabolic model contains the stoichiometric matrix (S) with reactions and metabolites. S is a stoichiometric representation of metabolic networks corresponding to the reactions in the biochemical pathway. In each column of the S matrix is a biochemical reaction (n) and in each row is a precise metabolite (m). There is a stoichiometric coefficient of zero, which means that metabolite does not participate in that distinct reaction. The coefficient also can be positive when the appropriate metabolite is produced, or negative for every metabolite consumed.
%
% <img src="figures/S-matrix.png" width="500">

% %% [markdown]
% ## Begin by initializing the Cobra toolbox

% %% [markdown]
% Initialize the Cobra Toolbox using the |initCobraToolbox| function.

% %%
initCobraToolbox
% Out:
%       _____   _____   _____   _____     _____     |
%      /  ___| /  _  \ |  _  \ |  _  \   / ___ \    |   COnstraint-Based Reconstruction and Analysis
%      | |     | | | | | |_| | | |_| |  | |___| |   |   The COBRA Toolbox - 2017
%      | |     | | | | |  _  { |  _  /  |  ___  |   |
%      | |___  | |_| | | |_| | | | \ \  | |   | |   |   Documentation:
%      \_____| \_____/ |_____/ |_|  \_\ |_|   |_|   |   http://opencobra.github.io/cobratoolbox
%                                                   |
%
%  > Checking if git is installed ...  Done.
%  > Checking if the repository is tracked using git ...  Done.
%  > Checking if curl is installed ...  Done.
%  > Checking if remote can be reached ...  Done.
%  > Initializing and updating submodules ... Done.
%  > Define CB map output... set to svg.
%  > Retrieving models ...   Done.
%  > TranslateSBML is installed and working properly.
%  > Configuring solver environment variables ...
%    - ILOG_CPLEX_PATH:  --> set this path manually after installing the solver
%    - GUROBI_PATH:  --> set this path manually after installing the solver
%    - TOMLAB_PATH:  --> set this path manually after installing the solver
%    - MOSEK_PATH:  --> set this path manually after installing the solver
%    Done.
%  > Checking available solvers and solver interfaces ... Done.
%  > Saving the MATLAB path ... Done.
%    - The MATLAB path was saved in the default location. > Setting default solvers ... Done.
%
%  > Summary of available solvers and solver interfaces
%
%                       Support       LP    MILP    QP    MIQP    NLP
%                     ____________    __    ____    __    ____    ___
%
%     cplex_direct    full            0     0       0     0       -
%     dqqMinos        full            0     -       -     -       -
%     glpk            full            1     1       -     -       -
%     gurobi          full            0     0       0     0       -
%     ibm_cplex       full            0     0       0     0       -
%     matlab          full            1     -       -     -       1
%     mosek           full            0     0       0     -       -
%     pdco            full            1     -       1     -       1
%     quadMinos       full            0     -       -     -       0
%     tomlab_cplex    full            0     0       0     0       -
%     opti            experimental    0     0       0     0       0
%     qpng            experimental    -     -       1     -       -
%     tomlab_snopt    experimental    -     -       -     -       0
%     gurobi_mex      legacy          0     0       0     0       -
%     lindo_old       legacy          0     -       -     -       -
%     lindo_legacy    legacy          0     -       -     -       -
%     lp_solve        legacy          1     -       -     -       -
%     ----------      ----------
%     Total           -               4     1       2     0       2
%
%  + Legend: - = not applicable, 0 = solver not compatible or not installed, 1 = solver installed.
%
%  > You can solve LP problems using: 'glpk' - 'matlab' - 'pdco' - 'lp_solve'
%  > You can solve MILP problems using: 'glpk'
%  > You can solve QP problems using: 'pdco' - 'qpng'
%  > You cannot solve MIQP problems. Consider installing an MIQP solver.
%  > You can solve NLP problems using: 'matlab' - 'pdco'
%
% You cannot update your fork using updateCobraToolbox(). Please use the MATLAB.devTools (https://github.com/opencobra/MATLAB.devTools).

% %% [markdown]
% ### Next, load a load the model into the directory

% %% [markdown]
% To load a model from a MAT-file, you can simply use load('the filename (with or without file extension))'.

% %%
% load model
load('Model_iJB785.mat');

% %% [markdown]
% Once the model is loaded it can be used directly with The COBRA Toolbox functions. To view the data stored in the model use the following command.

% %% [markdown]
% If you have matlab, use the command |open model|, otherwise open the model by typing the variable name

% %%
model
% Out:
% model =
%
%            mets: {769x1 cell}
%        metNames: {769x1 cell}
%     metFormulas: {768x1 cell}
%           genes: {785x1 cell}
%         grRules: {851x1 cell}
%            rxns: {851x1 cell}
%        rxnNames: {851x1 cell}
%      subSystems: {851x1 cell}
%          csense: 'EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE...'
%               S: [769x851 double]
%              lb: [851x1 double]
%              ub: [851x1 double]
%               b: [769x1 double]
%               c: [851x1 double]
%             rev: [851x1 int32]
%     description: 'iJB785'
%           rules: {851x1 cell}
%      rxnGeneMat: [851x785 double]

% %% [markdown]
% You can see that there are 769 metabolites, 785 genes, and 851 reactions in the model names iJB785.
% It is required for a model to consist of the descriptive fields: model.mets and model.rxns, which represent the metabolites and the reactions respectively.

% %%
model.rxns
% Out:
% ans =
%
%     'QULNS'
%     'ORNDC'
%     'LEUTA'
%     'MSBENZMT'
%     'DESAT18a'
%     'FUM'
%     'PHYFXOR'
%     'VPAMTr'
%     'GLYCL'
%     'NDPK7'
%     'GTPCI'
%     'MTHFC'
%     'LYCBC2'
%     'ORNTA'
%     'UPPDC1'
%     'GARFT'
%     'H4THDPR'
%     'UDPG4E'
%     'GLCS3'
%     'ASPTA'
%     'PRAGSr'
%     'ACKr'
%     'KAS14'
%     'UDCPDPS'
%     'GLNS'
%     'SHKK'
%     'G1PACT'
%     '5DOAN'
%     'OHPBAT'
%     'Htex'
%     '3HAD60'
%     'PGI'
%     'PNTK'
%     '3OAR60'
%     'ACGK'
%     'LEUabcpp'
%     'G5SD'
%     'DTMPK'
%     'NOR'
%     'NDH-1(1)um'
%     'AOOA'
%     'CMPA'
%     'U23GAAT2'
%     'PGK'
%     'IMPD'
%     'LPOR'
%     'CHRPL'
%     'GCALDDy'
%     'RNDR1'
%     'AIRC2'
%     'MTAP'
%     'HEMEAS'
%     'DHORD3um'
%     'TRPS1'
%     'NNATr'
%     '3OAR120'
%     'HISTDb'
%     'SPS'
%     'ADCL'
%     'CYTK1'
%     'PSIum'
%     'Cobalt2abcppI'
%     'THRS'
%     'AOXPBDC'
%     'NAMNPP'
%     'PERD'
%     'DAPDC'
%     'COCHL'
%     '3OAR100'
%     'PFK_3'
%     'PPK2r'
%     'ZNabcpp'
%     'GLYDHDA'
%     'ANS'
%     'SUCBZL'
%     'ADPT'
%     'RNDR3'
%     'DHNANT'
%     'GND'
%     'O2tcx'
%     'TRPS3'
%     'DNTPPA'
%     'HOXGfx'
%     'TMPPP'
%     'TALA'
%     'ACONT'
%     'IGPS'
%     'HBZNPT'
%     'HSDyi'
%     'GLYOX'
%     'CBMD'
%     'AICART'
%     'UDPSQS'
%     'GK1'
%     'OXADC'
%     'PC6AS'
%     'PPND'
%     'IPDPS'
%     'H4THDPS'
%     'BM_PIGMENTS'
%     '3HAD160'
%     'HISTDa'
%     'ADSL1r'
%     'H2Otu_syn'
%     'ADOCBLS'
%     'PDS2'
%     'ALAALAr'
%     'ACOATA'
%     'GLCP2'
%     'GLYCK'
%     'MAN1PT'
%     'DMBZIDS2'
%     'CS'
%     'DMATT'
%     'PSP_L'
%     'NDPK3'
%     'G3PD2'
%     'PHYTES'
%     'MOHMT'
%     'FBA'
%     'BOF'
%     'ACLSa'
%     'ASADi'
%     'PSCVT'
%     'TYRTA'
%     'SERAT'
%     'DHFS'
%     'AMPMS3'
%     'ACBIPGT'
%     'ATPM'
%     'SEPHCHCS'
%     'NMNDA'
%     'IGPDH'
%     'OMPDC'
%     'DCTPD'
%     '3OAR80'
%     '3OAR180'
%     'GLUSfx'
%     'NADS2'
%     'GLUTRR'
%     'G1PTT'
%     'UAMAGS'
%     'FOLD3'
%     '3HAD100'
%     'MEHLER'
%     'GALUi'
%     'P5CR'
%     'PQH2tum'
%     'ICHORS'
%     '3OAS140'
%     'SBP'
%     'EAR60y'
%     'O2tu'
%     'SULabcpp'
%     'PPKr'
%     'BM_DNA'
%     'UAPGR'
%     'DHAD1'
%     'IPPS'
%     'PPBNGS'
%     'PRE3BS'
%     'PHYTES2'
%     '3HAD80'
%     'LTHRK'
%     'PPS'
%     'ADCPS2'
%     'GF6PTA'
%     'O2tpp'
%     'PGMT'
%     '3OAR140'
%     'NMNS'
%     'NDPK2'
%     'AGDI'
%     'LPADSS2'
%     'DPR'
%     'H2Otex'
%     'TKT2'
%     'DM_for_c'
%     'HEX7'
%     'PPNCL2'
%     'CYTBD4cm'
%     'GLYCOR_nadp'
%     'CHORS'
%     '3OAR160'
%     'ADMDC'
%     'PPPGO2'
%     'ASP1DC'
%     'DNAMTn2r'
%     'MI3PP'
%     'CYSS_2'
%     'PROHX'
%     'FTHFD'
%     'MEPCT'
%     'PDX5POi'
%     'PPCDC'
%     'NTD6'
%     'NNDMBRT'
%     'ASNN'
%     'PRAIS'
%     'ORNTAC'
%     'SUCBZS'
%     'HGYDAS'
%     'GGDPR'
%     'ASPCT'
%     'PPNDH'
%     'NMNAT'
%     'ME2'
%     'APRAUR'
%     'SADT'
%     'LDH_D'
%     'DPCOAK'
%     'O2tex'
%     'DPOR'
%     'ARGSL'
%     'HSK'
%     'EAR120y'
%     'BCAROHX2'
%     'HPPK'
%     'PPNCL3'
%     'AHCi'
%     'G6PDH2r'
%     'MPPM'
%     'CPPPGO2'
%     'PC17M'
%     'ACCOAC'
%     'GLUCYS'
%     'CYNL'
%     'CYOOum'
%     'ACLSb'
%     'DNMPPA'
%     'METS'
%     'TRPS2'
%     'PRUK'
%     'FNOR'
%     'GART'
%     'G5SADs'
%     'AMPQT'
%     'SPMDabcpp'
%     'DHAD2'
%     'PRAMPC'
%     '3OAS80'
%     'G1PCTYT'
%     'BM_CELL_WALL'
%     'CA2abcpp'
%     'UHGADA2'
%     'ASPO6'
%     'ASPK'
%     'DXPS'
%     'PRATPP'
%     'DDPGA'
%     'NH4tpp'
%     'PAPSR'
%     'NAD_H2'
%     'CYRDAAT'
%     'NTPP8'
%     'PC11M'
%     'ARGabcpp'
%     'ARGOXRum'
%     'PMDPHT'
%     'DAPE'
%     'LYCBC1'
%     'RB15BPtcx'
%     'GLCBRAN3'
%     'DB4PS'
%     'DXPRIi'
%     'GTPCII'
%     'RBFSa'
%     'GLUTRS'
%     'ALDD2y'
%     'EHGLAT'
%     'METAT'
%     'DHORTS'
%     'PDX5PS2'
%     'ARGDC'
%     'GAPDi_nadp'
%     'GLXO3r'
%     'PGCD'
%     'AIRC3'
%     'UMPK'
%     'CBPS'
%     '3HAD180'
%     'IMDHT'
%     'RZ5PP'
%     'RBFSb'
%     'GLNabcpp'
%     'NDPK8'
%     'PC6YM'
%     'DDPA'
%     'ACOTA'
%     'FBP'
%     'MNabc_1'
%     'NTD7'
%     'MPOMMM'
%     'MTHFD'
%     'PANTS'
%     'TMPK'
%     'ASNS1'
%     'AGPR'
%     'KARI_23dhmp'
%     'IPMD'
%     '3PGtcx'
%     'CDPMEK'
%     'CITCIa'
%     'SUCDum'
%     'DVOCHR'
%     'H2CO3_NAt_syn'
%     'HEMEOS'
%     'ALAD_L'
%     'RPE'
%     'MPOMT'
%     'NDHPQRum'
%     'UAMAS'
%     'CITCIb'
%     'BPNT2'
%     'BM_COFACTORS'
%     'DCTPD2'
%     'HSERTA'
%     'NDPK1'
%     'PGL'
%     'EAR160y'
%     'MECDPDHf'
%     'MTHFR3_1'
%     '3HAD140'
%     'FBA3'
%     'DAPNH4T'
%     'MG2uabcpp'
%     'HCO3E_1_cx'
%     'ACODA'
%     'GLU5K'
%     'EAR100y'
%     'PGM'
%     'ASPOb'
%     'DM_h2_c'
%     'ACS'
%     'PKETX'
%     'AMPTASECG'
%     'SHCHCS3'
%     'ATPPRT'
%     'NDH-1(4)um'
%     'UAGCVT'
%     'TDPGDH'
%     'ADSL2r'
%     'PRASCSi'
%     'MG2tex'
%     'HPROb'
%     'NTPP2'
%     'TRDR'
%     'PKETF'
%     'NDPK6'
%     'GLUPRT'
%     'PTRCabcpp'
%     'UPP3MT'
%     'DHNCOAS'
%     'MCOATA'
%     'PMPK'
%     'HMBS'
%     'PGLYCP'
%     'UAGAAT2'
%     'HTHRPDH'
%     'BCT1_syn'
%     'IPDDI'
%     'GLYALDDy'
%     'CITMS'
%     'IMPC'
%     'OMCDC'
%     'Htcx'
%     'DHQTi'
%     'SPODM'
%     'MAN6PI'
%     '3OAS120'
%     'PGAMT'
%     'ZDS'
%     'PSERT'
%     'HISTP'
%     'NNDPR'
%     'ADSK'
%     'MECDPS'
%     'CUabcpp'
%     'ADCYRS'
%     'RBPCcx'
%     '3HAD40_1'
%     'EAR180x'
%     'GTHRDH'
%     'PRAIi'
%     'CYNTtabcpp'
%     'TRSARyr'
%     'PTPATi'
%     'PC6AR'
%     'Kabcpp'
%     'ENO'
%     'TDPDRR'
%     'PRFGS'
%     'PC8XM'
%     '3OAS60'
%     'GMPS2'
%     'RBFK'
%     'NTRIRfx'
%     'GTHPi'
%     'ARGSS'
%     'SPTr'
%     'H2Otpp'
%     'TDPDRE'
%     'GTHOr'
%     'SHK3Dr'
%     'CYRDAR'
%     'ORPT'
%     'GRTT'
%     'TRDRf'
%     'BM_MEM_LIPIDS'
%     'PRPPS'
%     'KARA1i'
%     'SPRMS'
%     'FCLT'
%     'PPA'
%     'DHQS'
%     'ANPRT'
%     'ADK1'
%     'UPP3S'
%     'NDPK5'
%     'NDHPQRcm'
%     'DHNPA_1'
%     'NDPK4'
%     'RNDR4'
%     'NADK'
%     '3OAR40_1'
%     'TKT1'
%     'NO3abcpp'
%     'FE3abcpp'
%     'MOBDabcpp'
%     'NPHBDC'
%     'NPDPS'
%     'NI2uabcpp'
%     'HCO3tcx'
%     'RNDR2'
%     'KARI'
%     'EAR40y'
%     'NADTRHD'
%     'DHNCOAT'
%     'BM_PROTEIN'
%     '3OAS100'
%     'G1SAT'
%     'ILETA'
%     'PDS1'
%     'UAAGDS'
%     'GLCDBRAN3'
%     'HEX1'
%     'ATPSum'
%     'CHPHYS'
%     'BCAROHX'
%     'GLYCLTDx'
%     'PIuabcpp'
%     'PC20M'
%     'ADSS'
%     'BM_RNA'
%     'DM_dialurate_c'
%     'THRPD'
%     'TMDS3'
%     'DHFR'
%     'ACGS'
%     'VALTA'
%     'AFAT'
%     'GLYOX_1'
%     'EAR140y'
%     'FRTT'
%     'CTPS2'
%     'DESAT16a'
%     'CO2tex'
%     'GTHS'
%     'UAGDP'
%     'DADK'
%     'MPOMC1'
%     'Nat_Kpp'
%     '3OAS180'
%     'ARGDHpp'
%     'EAR80y'
%     'ERTHMMOR'
%     'PDH'
%     'MPML'
%     'USHD2'
%     'TPI'
%     'DHPPDA'
%     'PRMICI'
%     'CYTBD4um'
%     'DM_co_c'
%     'CAT'
%     'GLUR'
%     'ALAR'
%     'SULR'
%     'NAt3ipp'
%     'ADCS'
%     'UGMDDS'
%     'BM_CARB'
%     'ICDHyr'
%     'ACHBSb'
%     'MTRI'
%     'SPMS'
%     'AHSERL2'
%     'PEPC'
%     'PHETA1'
%     'CHORM'
%     'GAPD'
%     'PQH2tcm'
%     'CPPPGO'
%     'URIDK2r'
%     'OCBT'
%     'E4PD'
%     'IMDHT_3c2hmp'
%     'GLGC'
%     'PYK'
%     '3HAD120'
%     '2PGLYCtcx'
%     'MPOMOR'
%     '3OAS160'
%     'IG3PS'
%     'DMPPS_syn'
%     'NTRARf2'
%     'G6PDA'
%     'PFK'
%     'CA2t2pp'
%     'DM_5drib_c'
%     'RPI'
%     'FMNRy'
%     'ANS2'
%     'GHMT2r'
%     'BPNT'
%     'PSIIum'
%     'CBFCum'
%     'SK_amylose_c'
%     'SK_14glucan_c'
%     'SK_glycogen_c'
%     'EX_h2o_e'
%     'EX_o2_e'
%     'EX_co2_e'
%     'EX_leu__L_e'
%     'EX_cobalt2_e'
%     'EX_zn2_e'
%     'EX_so4_e'
%     'EX_spmd_e'
%     'EX_ca2_e'
%     'EX_nh4_e'
%     'EX_arg__L_e'
%     'EX_gln__L_e'
%     'EX_mn2_e'
%     'EX_hco3_e'
%     'EX_mg2_e'
%     'EX_ptrc_e'
%     'EX_fe2_e'
%     'EX_cu2_e'
%     'EX_k_e'
%     'EX_no3_e'
%     'EX_fe3_e'
%     'EX_mobd_e'
%     'EX_ni2_e'
%     'EX_na1_e'
%     'EX_cynt_e'
%     'EX_h_e'
%     'FE3tex'
%     'FE2tex'
%     'NI2tex'
%     'MNtex'
%     'COBALT2tex'
%     'CU2tex'
%     'Zn2tex'
%     'SPMDtex'
%     'LEUtex'
%     'HCO3tex'
%     'GLNtex'
%     'CYNTtex'
%     'ARGtex'
%     'MOBDtex'
%     'NH4tex'
%     'SO4tex'
%     'PTRCtex'
%     'NO3tex'
%     'NAtex'
%     'CA2tex'
%     'Ktex'
%     'CO2tpp'
%     'EX_pi_e'
%     'PItex'
%     'MDRPD'
%     'ENOPH'
%     'ARD'
%     'UNK3'
%     'PHYPQOX'
%     'ZISO'
%     'ZCARDS'
%     'PLYCOI'
%     'CHLADMT'
%     'PHEOASE'
%     'PHEOX'
%     'PHYTK'
%     'TRNFE'
%     'PTHPS'
%     'SPR'
%     'THBTGT'
%     'NADDP'
%     'CYSDS'
%     'THISAT'
%     'THII'
%     'GLYCOX1'
%     'GLYCOX2'
%     'DXYTST'
%     'THZT'
%     'SHS1'
%     'MALCOAMT'
%     'OGMEACPS'
%     'OGMEACPR'
%     'OGMEACPD'
%     'EGMEACPR'
%     'OPMEACPS'
%     'OPMEACPR'
%     'OPMEACPD'
%     'EPMEACPR'
%     'PMEACPE'
%     'AOXSr2'
%     'AMAOTr'
%     'DBTS'
%     'BTS6'
%     'BACCL'
%     'BTNPL2'
%     'LIPOCT'
%     'LIPOS2'
%     'LIPATPT'
%     'LIPAMPL'
%     'MEOHtpp'
%     'MEOHtex'
%     'DM_amob_c'
%     'AGTi'
%     'ADNK1'
%     'CPH4S'
%     'CDGS'
%     'CCGS'
%     'CDGR'
%     'QUERT'
%     'SAMTRI'
%     'EPXQR'
%     'UPPRT'
%     'UDPGD'
%     'UDPGLDC'
%     'GMAND'
%     'GFUCS'
%     'ALCD19'
%     'CDPGLC46DH'
%     'SPP'
%     'NDH-1(2)um'
%     'NDH-1(3)um'
%     'KAS15'
%     'AACPS6'
%     'ALDR18'
%     'ALDDC17'
%     'G3PAT160'
%     'G3PAT161'
%     'G3PAT1819Z'
%     'AGPAT160'
%     'AGPATACP_HDE_PALM'
%     'AGPAT161'
%     'AGPATACP_OLE_HDE'
%     'AGPATACP_OLE_PALM'
%     'PAPA160'
%     'PAPA_HDE_PALM'
%     'PAPA161'
%     'PAPA_OLE_HDE'
%     'PAPA_OLE_PALM'
%     'SQDGS_PALM_PALM'
%     'SQDGS_HDE_PALM'
%     'DGDGS_HDE_PALM'
%     'DGDGS_HDE_HDE'
%     'DGDGS_OLE_HDE'
%     'CDPDAGS_OLE_PALM'
%     'PGPS_OLE_PALM'
%     'PGPP_OLE_PALM'
%     'DAGK160'
%     'DAGK_HDE_PALM'
%     'DAGK161'
%     'DAGK_OLE_HDE'
%     'DAGK_OLE_PALM'
%     'GLUDGS_HDE_PALM'
%     'GLUDGE_HDE_PALM'
%     'GLUDGS_HDE_HDE'
%     'GLUDGE_HDE_HDE'
%     'GLUDGS_OLE_HDE'
%     'GLUDGE_OLE_HDE'
%     'GLUDGS_OLE_PALM'
%     'GLUDGE_OLE_PALM'
%     'DGDGS_OLE_PALM'
%     'H2Otcx'
%     'GLNTRS'
%     'TYRTRS'
%     'METTRS'
%     'SERTRS'
%     'GLYTRS'
%     'PROTRS'
%     'CYSTRS'
%     'ARGTRS'
%     'TRPTRS'
%     'PHETRS'
%     'HISTRS'
%     'ASNTRS'
%     'ASPTRS'
%     'THRTRS'
%     'LEUTRS'
%     'ILETRS'
%     'LYSTRS'
%     'ALATRS'
%     'VALTRS'
%     'FMETTRS'
%     'EX_photon410_e'
%     'EX_photon430_e'
%     'EX_photon450_e'
%     'EX_photon470_e'
%     'EX_photon490_e'
%     'EX_photon510_e'
%     'EX_photon530_e'
%     'EX_photon550_e'
%     'EX_photon570_e'
%     'EX_photon590_e'
%     'EX_photon610_e'
%     'EX_photon630_e'
%     'EX_photon650_e'
%     'EX_photon670_e'
%     'EX_photon690_e'
%     'ZXANHX'
%     'CXANHX'
%     'PHOA410um'
%     'PHOA430um'
%     'PHOA450um'
%     'PHOA470um'
%     'PHOA490um'
%     'PHOA510um'
%     'PHOA530um'
%     'PHOA550um'
%     'PHOA570um'
%     'PHOA590um'
%     'PHOA610um'
%     'PHOA630um'
%     'PHOA650um'
%     'PHOA670um'
%     'PHOA690um'
%     'DM_pho_loss_c'
%     'ETCHLAS'
%     'ETBCARO'
%     'ETCPC'
%     'STACPSI'
%     'A5PISO'
%     'KDOPS'
%     'KDOPP'
%     'KDOCT2'
%     'MOAT'
%     'UAG2E'
%     'ACGAMT'
%     'ACMAMT'
%     'ICLIPAS'
%     'ICLIPAabcpp'
%     'OANTS'
%     'OANTIabcpp'
%     'OANTILpp'
%     'COLIPAabcex'
%     'MPTG'
%     'MPTG2'
%     'MCTP2App'
%     'MCTP1App'
%     'MCTP1Bpp'
%     'MDDCP1pp'
%     'MDDCP2pp'
%     'MDDCP3pp'
%     'MDDCP4pp'
%     'MDDCP5pp'
%     'MDDEP1pp'
%     'MDDEP2pp'
%     'MDDEP3pp'
%     'MDDEP4pp'
%     'MLDCP1App'
%     'MLDCP1Bpp'
%     'MLDCP2App'
%     'MLDCP2Bpp'
%     'MLTGY1pp'
%     'MLTGY2pp'
%     'MLTGY3pp'
%     'MLTGY4pp'
%     'AGM4PA'
%     'AGM4PApp'
%     'AGM4PCP'
%     'AGM4PH'
%     'AGM3PApp'
%     'AGMH'
%     'AGM3PH'
%     'AM4PCP'
%     '4PCP'
%     'AM3PA'
%     'AM4PA'
%     'LADGMDH'
%     'UM4PL'
%     'ALAGLUE'
%     'UM3PL'
%     'UM4PCP'
%     'LALGP'
%     'AGM4Pt2pp'
%     'AGMt2pp'
%     '4PEPTabcpp'
%     'UAGPT3'
%     'UDCPDP'
%     'PAPPT3'
%     'ALAALAD'
%     'DALAabcpp'
%     'ALAALAabcpp'
%     '3PEPTabcpp'
%     'PCHLDA430'
%     'PCHLDA650'
%     'EX_meoh_e'
%     'PFOR'
%     'NO2tabcpp'
%     'NO2tex'
%     'Htabcpp'
%     'ETAPCPSII'
%     'PSICSum'
%     'PSIICSum'
%     'STCHLPSIum'
%     'DEXZEAX'
%     'CELLSYN'
%     'ADPGDP'
%     'ALCD1'
%     'FALGTHLs'
%     'FALDH2'
%     'SFGTHi'
%     'GGCLUT2'
%     'OPAH'
%     'ACGAMK'
%     'AMANAPEr'
%     'AGDC'
%     'ANHMK'
%     'ACM6PH'
%     'SUCR'
%     'CLt3_1pp'
%     'Cltex'
%     'EX_cl_e'
%     'Ktu'
%     'FDH6'
%     'DM_fum_c'
%     'DM_succ_c'
%     'DM_akg_c'
%     'NGAM_D1um'
%     'PSICRum'
%     'PSIICRum'
%     'DM_ac_c'
%     'DM_lac__D_c'
%     'ASPO5'
%     'MNHNAtpp'
%     'PCXHtpp'
%     'NGAM'
%     'DM_pkcc'

% %% [markdown]
% The fields in a COBRA model are commonly column vectors, which is important to note when writing functions manipulating these fields.
% There are a few more fields present in each COBRA model:
% model.lb, indicating the lower bounds of each reaction, and model.ub indicating the upper bound of a reaction.

% %%
% this displays an array with reaction names and flux bounds.
[{'Reaction ID', 'Lower Bound', 'Upper Bound'};...   
 model.rxns, num2cell(model.lb), num2cell(model.ub)]
% Out:
% ans =
%
%     'Reaction ID'          'Lower Bound'    'Upper Bound'
%     'QULNS'                [          0]    [ 1.0000e+09]
%     'ORNDC'                [          0]    [ 1.0000e+09]
%     'LEUTA'                [-1.0000e+09]    [ 1.0000e+09]
%     'MSBENZMT'             [          0]    [ 1.0000e+09]
%     'DESAT18a'             [-1.0000e+09]    [ 1.0000e+09]
%     'FUM'                  [-1.0000e+09]    [ 1.0000e+09]
%     'PHYFXOR'              [          0]    [ 1.0000e+09]
%     'VPAMTr'               [-1.0000e+09]    [          0]
%     'GLYCL'                [          0]    [ 1.0000e+09]
%     'NDPK7'                [-1.0000e+09]    [ 1.0000e+09]
%     'GTPCI'                [          0]    [ 1.0000e+09]
%     'MTHFC'                [-1.0000e+09]    [ 1.0000e+09]
%     'LYCBC2'               [-1.0000e+09]    [ 1.0000e+09]
%     'ORNTA'                [          0]    [          0]
%     'UPPDC1'               [          0]    [ 1.0000e+09]
%     'GARFT'                [          0]    [ 1.0000e+09]
%     'H4THDPR'              [          0]    [ 1.0000e+09]
%     'UDPG4E'               [-1.0000e+09]    [ 1.0000e+09]
%     'GLCS3'                [          0]    [ 1.0000e+09]
%     'ASPTA'                [-1.0000e+09]    [ 1.0000e+09]
%     'PRAGSr'               [          0]    [ 1.0000e+09]
%     'ACKr'                 [-1.0000e+09]    [ 1.0000e+09]
%     'KAS14'                [          0]    [ 1.0000e+09]
%     'UDCPDPS'              [          0]    [ 1.0000e+09]
%     'GLNS'                 [          0]    [ 1.0000e+09]
%     'SHKK'                 [          0]    [ 1.0000e+09]
%     'G1PACT'               [          0]    [ 1.0000e+09]
%     '5DOAN'                [          0]    [ 1.0000e+09]
%     'OHPBAT'               [-1.0000e+09]    [ 1.0000e+09]
%     'Htex'                 [-1.0000e+09]    [ 1.0000e+09]
%     '3HAD60'               [-1.0000e+09]    [ 1.0000e+09]
%     'PGI'                  [-1.0000e+09]    [ 1.0000e+09]
%     'PNTK'                 [          0]    [ 1.0000e+09]
%     '3OAR60'               [-1.0000e+09]    [ 1.0000e+09]
%     'ACGK'                 [          0]    [ 1.0000e+09]
%     'LEUabcpp'             [          0]    [ 1.0000e+09]
%     'G5SD'                 [          0]    [ 1.0000e+09]
%     'DTMPK'                [-1.0000e+09]    [ 1.0000e+09]
%     'NOR'                  [          0]    [ 1.0000e+09]
%     'NDH-1(1)um'           [          0]    [ 1.0000e+09]
%     'AOOA'                 [-1.0000e+09]    [ 1.0000e+09]
%     'CMPA'                 [          0]    [ 1.0000e+09]
%     'U23GAAT2'             [          0]    [ 1.0000e+09]
%     'PGK'                  [-1.0000e+09]    [ 1.0000e+09]
%     'IMPD'                 [          0]    [ 1.0000e+09]
%     'LPOR'                 [          0]    [ 1.0000e+09]
%     'CHRPL'                [          0]    [ 1.0000e+09]
%     'GCALDDy'              [          0]    [ 1.0000e+09]
%     'RNDR1'                [          0]    [ 1.0000e+09]
%     'AIRC2'                [          0]    [ 1.0000e+09]
%     'MTAP'                 [          0]    [ 1.0000e+09]
%     'HEMEAS'               [-1.0000e+09]    [ 1.0000e+09]
%     'DHORD3um'             [          0]    [ 1.0000e+09]
%     'TRPS1'                [          0]    [ 1.0000e+09]
%     'NNATr'                [-1.0000e+09]    [ 1.0000e+09]
%     '3OAR120'              [-1.0000e+09]    [ 1.0000e+09]
%     'HISTDb'               [          0]    [ 1.0000e+09]
%     'SPS'                  [          0]    [ 1.0000e+09]
%     'ADCL'                 [          0]    [ 1.0000e+09]
%     'CYTK1'                [-1.0000e+09]    [ 1.0000e+09]
%     'PSIum'                [          0]    [ 1.0000e+09]
%     'Cobalt2abcppI'        [          0]    [ 1.0000e+09]
%     'THRS'                 [          0]    [ 1.0000e+09]
%     'AOXPBDC'              [          0]    [ 1.0000e+09]
%     'NAMNPP'               [-1.0000e+09]    [ 1.0000e+09]
%     'PERD'                 [          0]    [ 1.0000e+09]
%     'DAPDC'                [          0]    [ 1.0000e+09]
%     'COCHL'                [          0]    [ 1.0000e+09]
%     '3OAR100'              [-1.0000e+09]    [ 1.0000e+09]
%     'PFK_3'                [          0]    [ 1.0000e+09]
%     'PPK2r'                [-1.0000e+09]    [ 1.0000e+09]
%     'ZNabcpp'              [-1.0000e+09]    [ 1.0000e+09]
%     'GLYDHDA'              [-1.0000e+09]    [ 1.0000e+09]
%     'ANS'                  [          0]    [ 1.0000e+09]
%     'SUCBZL'               [          0]    [ 1.0000e+09]
%     'ADPT'                 [-1.0000e+09]    [ 1.0000e+09]
%     'RNDR3'                [          0]    [ 1.0000e+09]
%     'DHNANT'               [          0]    [ 1.0000e+09]
%     'GND'                  [          0]    [ 1.0000e+09]
%     'O2tcx'                [          0]    [ 1.0000e+09]
%     'TRPS3'                [          0]    [ 1.0000e+09]
%     'DNTPPA'               [          0]    [ 1.0000e+09]
%     'HOXGfx'               [          0]    [ 1.0000e+09]
%     'TMPPP'                [          0]    [ 1.0000e+09]
%     'TALA'                 [          0]    [ 1.0000e+09]
%     'ACONT'                [-1.0000e+09]    [ 1.0000e+09]
%     'IGPS'                 [          0]    [ 1.0000e+09]
%     'HBZNPT'               [          0]    [ 1.0000e+09]
%     'HSDyi'                [          0]    [ 1.0000e+09]
%     'GLYOX'                [          0]    [ 1.0000e+09]
%     'CBMD'                 [          0]    [ 1.0000e+09]
%     'AICART'               [          0]    [ 1.0000e+09]
%     'UDPSQS'               [          0]    [ 1.0000e+09]
%     'GK1'                  [-1.0000e+09]    [ 1.0000e+09]
%     'OXADC'                [          0]    [ 1.0000e+09]
%     'PC6AS'                [          0]    [ 1.0000e+09]
%     'PPND'                 [          0]    [ 1.0000e+09]
%     'IPDPS'                [          0]    [ 1.0000e+09]
%     'H4THDPS'              [          0]    [ 1.0000e+09]
%     'BM_PIGMENTS'          [          0]    [ 1.0000e+09]
%     '3HAD160'              [-1.0000e+09]    [ 1.0000e+09]
%     'HISTDa'               [          0]    [ 1.0000e+09]
%     'ADSL1r'               [          0]    [ 1.0000e+09]
%     'H2Otu_syn'            [-1.0000e+09]    [ 1.0000e+09]
%     'ADOCBLS'              [          0]    [ 1.0000e+09]
%     'PDS2'                 [          0]    [ 1.0000e+09]
%     'ALAALAr'              [          0]    [ 1.0000e+09]
%     'ACOATA'               [          0]    [ 1.0000e+09]
%     'GLCP2'                [          0]    [ 1.0000e+09]
%     'GLYCK'                [          0]    [ 1.0000e+09]
%     'MAN1PT'               [          0]    [ 1.0000e+09]
%     'DMBZIDS2'             [          0]    [ 1.0000e+09]
%     'CS'                   [          0]    [ 1.0000e+09]
%     'DMATT'                [          0]    [ 1.0000e+09]
%     'PSP_L'                [          0]    [ 1.0000e+09]
%     'NDPK3'                [-1.0000e+09]    [ 1.0000e+09]
%     'G3PD2'                [-1.0000e+09]    [ 1.0000e+09]
%     'PHYTES'               [          0]    [ 1.0000e+09]
%     'MOHMT'                [          0]    [ 1.0000e+09]
%     'FBA'                  [-1.0000e+09]    [ 1.0000e+09]
%     'BOF'                  [          0]    [    2000000]
%     'ACLSa'                [          0]    [ 1.0000e+09]
%     'ASADi'                [          0]    [ 1.0000e+09]
%     'PSCVT'                [-1.0000e+09]    [ 1.0000e+09]
%     'TYRTA'                [-1.0000e+09]    [ 1.0000e+09]
%     'SERAT'                [          0]    [ 1.0000e+09]
%     'DHFS'                 [          0]    [ 1.0000e+09]
%     'AMPMS3'               [-1.0000e+09]    [ 1.0000e+09]
%     'ACBIPGT'              [          0]    [ 1.0000e+09]
%     'ATPM'                 [          0]    [ 1.0000e+09]
%     'SEPHCHCS'             [          0]    [ 1.0000e+09]
%     'NMNDA'                [          0]    [ 1.0000e+09]
%     'IGPDH'                [          0]    [ 1.0000e+09]
%     'OMPDC'                [          0]    [ 1.0000e+09]
%     'DCTPD'                [          0]    [ 1.0000e+09]
%     '3OAR80'               [-1.0000e+09]    [ 1.0000e+09]
%     '3OAR180'              [-1.0000e+09]    [ 1.0000e+09]
%     'GLUSfx'               [          0]    [ 1.0000e+09]
%     'NADS2'                [          0]    [ 1.0000e+09]
%     'GLUTRR'               [          0]    [ 1.0000e+09]
%     'G1PTT'                [          0]    [ 1.0000e+09]
%     'UAMAGS'               [          0]    [ 1.0000e+09]
%     'FOLD3'                [          0]    [ 1.0000e+09]
%     '3HAD100'              [-1.0000e+09]    [ 1.0000e+09]
%     'MEHLER'               [          0]    [ 1.0000e+09]
%     'GALUi'                [-1.0000e+09]    [ 1.0000e+09]
%     'P5CR'                 [          0]    [ 1.0000e+09]
%     'PQH2tum'              [          0]    [ 1.0000e+09]
%     'ICHORS'               [-1.0000e+09]    [ 1.0000e+09]
%     '3OAS140'              [          0]    [ 1.0000e+09]
%     'SBP'                  [          0]    [ 1.0000e+09]
%     'EAR60y'               [          0]    [ 1.0000e+09]
%     'O2tu'                 [-1.0000e+09]    [ 1.0000e+09]
%     'SULabcpp'             [          0]    [ 1.0000e+09]
%     'PPKr'                 [-1.0000e+09]    [ 1.0000e+09]
%     'BM_DNA'               [          0]    [ 1.0000e+09]
%     'UAPGR'                [-1.0000e+09]    [ 1.0000e+09]
%     'DHAD1'                [          0]    [ 1.0000e+09]
%     'IPPS'                 [          0]    [ 1.0000e+09]
%     'PPBNGS'               [          0]    [ 1.0000e+09]
%     'PRE3BS'               [          0]    [ 1.0000e+09]
%     'PHYTES2'              [          0]    [ 1.0000e+09]
%     '3HAD80'               [-1.0000e+09]    [ 1.0000e+09]
%     'LTHRK'                [          0]    [ 1.0000e+09]
%     'PPS'                  [          0]    [ 1.0000e+09]
%     'ADCPS2'               [          0]    [ 1.0000e+09]
%     'GF6PTA'               [-1.0000e+09]    [ 1.0000e+09]
%     'O2tpp'                [-1.0000e+09]    [ 1.0000e+09]
%     'PGMT'                 [-1.0000e+09]    [ 1.0000e+09]
%     '3OAR140'              [-1.0000e+09]    [ 1.0000e+09]
%     'NMNS'                 [-1.0000e+09]    [ 1.0000e+09]
%     'NDPK2'                [-1.0000e+09]    [ 1.0000e+09]
%     'AGDI'                 [          0]    [ 1.0000e+09]
%     'LPADSS2'              [          0]    [ 1.0000e+09]
%     'DPR'                  [-1.0000e+09]    [ 1.0000e+09]
%     'H2Otex'               [-1.0000e+09]    [ 1.0000e+09]
%     'TKT2'                 [-1.0000e+09]    [ 1.0000e+09]
%     'DM_for_c'             [          0]    [ 1.0000e+09]
%     'HEX7'                 [          0]    [ 1.0000e+09]
%     'PPNCL2'               [          0]    [ 1.0000e+09]
%     'CYTBD4cm'             [          0]    [ 1.0000e+09]
%     'GLYCOR_nadp'          [          0]    [ 1.0000e+09]
%     'CHORS'                [          0]    [ 1.0000e+09]
%     '3OAR160'              [-1.0000e+09]    [ 1.0000e+09]
%     'ADMDC'                [          0]    [ 1.0000e+09]
%     'PPPGO2'               [          0]    [ 1.0000e+09]
%     'ASP1DC'               [          0]    [ 1.0000e+09]
%     'DNAMTn2r'             [          0]    [ 1.0000e+09]
%     'MI3PP'                [          0]    [ 1.0000e+09]
%     'CYSS_2'               [          0]    [ 1.0000e+09]
%     'PROHX'                [          0]    [ 1.0000e+09]
%     'FTHFD'                [          0]    [ 1.0000e+09]
%     'MEPCT'                [          0]    [ 1.0000e+09]
%     'PDX5POi'              [-1.0000e+09]    [ 1.0000e+09]
%     'PPCDC'                [          0]    [ 1.0000e+09]
%     'NTD6'                 [-1.0000e+09]    [ 1.0000e+09]
%     'NNDMBRT'              [          0]    [ 1.0000e+09]
%     'ASNN'                 [          0]    [ 1.0000e+09]
%     'PRAIS'                [          0]    [ 1.0000e+09]
%     'ORNTAC'               [          0]    [ 1.0000e+09]
%     'SUCBZS'               [          0]    [ 1.0000e+09]
%     'HGYDAS'               [          0]    [ 1.0000e+09]
%     'GGDPR'                [          0]    [ 1.0000e+09]
%     'ASPCT'                [-1.0000e+09]    [ 1.0000e+09]
%     'PPNDH'                [          0]    [ 1.0000e+09]
%     'NMNAT'                [-1.0000e+09]    [ 1.0000e+09]
%     'ME2'                  [-1.0000e+09]    [ 1.0000e+09]
%     'APRAUR'               [          0]    [ 1.0000e+09]
%     'SADT'                 [          0]    [ 1.0000e+09]
%     'LDH_D'                [-1.0000e+09]    [          0]
%     'DPCOAK'               [          0]    [ 1.0000e+09]
%     'O2tex'                [-1.0000e+09]    [ 1.0000e+09]
%     'DPOR'                 [          0]    [          0]
%     'ARGSL'                [          0]    [ 1.0000e+09]
%     'HSK'                  [          0]    [ 1.0000e+09]
%     'EAR120y'              [          0]    [ 1.0000e+09]
%     'BCAROHX2'             [          0]    [ 1.0000e+09]
%     'HPPK'                 [-1.0000e+09]    [ 1.0000e+09]
%     'PPNCL3'               [          0]    [ 1.0000e+09]
%     'AHCi'                 [          0]    [ 1.0000e+09]
%     'G6PDH2r'              [          0]    [ 1.0000e+09]
%     'MPPM'                 [-1.0000e+09]    [ 1.0000e+09]
%     'CPPPGO2'              [          0]    [          0]
%     'PC17M'                [          0]    [ 1.0000e+09]
%     'ACCOAC'               [          0]    [ 1.0000e+09]
%     'GLUCYS'               [          0]    [ 1.0000e+09]
%     'CYNL'                 [          0]    [ 1.0000e+09]
%     'CYOOum'               [          0]    [          0]
%     'ACLSb'                [          0]    [ 1.0000e+09]
%     'DNMPPA'               [          0]    [ 1.0000e+09]
%     'METS'                 [          0]    [ 1.0000e+09]
%     'TRPS2'                [          0]    [ 1.0000e+09]
%     'PRUK'                 [          0]    [ 1.0000e+09]
%     'FNOR'                 [-1.0000e+09]    [ 1.0000e+09]
%     'GART'                 [          0]    [ 1.0000e+09]
%     'G5SADs'               [-1.0000e+09]    [ 1.0000e+09]
%     'AMPQT'                [          0]    [ 1.0000e+09]
%     'SPMDabcpp'            [          0]    [ 1.0000e+09]
%     'DHAD2'                [          0]    [ 1.0000e+09]
%     'PRAMPC'               [          0]    [ 1.0000e+09]
%     '3OAS80'               [          0]    [ 1.0000e+09]
%     'G1PCTYT'              [          0]    [ 1.0000e+09]
%     'BM_CELL_WALL'         [          0]    [ 1.0000e+09]
%     'CA2abcpp'             [          0]    [ 1.0000e+09]
%     'UHGADA2'              [          0]    [ 1.0000e+09]
%     'ASPO6'                [          0]    [ 1.0000e+09]
%     'ASPK'                 [          0]    [ 1.0000e+09]
%     'DXPS'                 [          0]    [ 1.0000e+09]
%     'PRATPP'               [          0]    [ 1.0000e+09]
%     'DDPGA'                [          0]    [ 1.0000e+09]
%     'NH4tpp'               [          0]    [ 1.0000e+09]
%     'PAPSR'                [          0]    [ 1.0000e+09]
%     'NAD_H2'               [-1.0000e+09]    [ 1.0000e+09]
%     'CYRDAAT'              [          0]    [ 1.0000e+09]
%     'NTPP8'                [          0]    [ 1.0000e+09]
%     'PC11M'                [          0]    [ 1.0000e+09]
%     'ARGabcpp'             [          0]    [ 1.0000e+09]
%     'ARGOXRum'             [          0]    [ 1.0000e+09]
%     'PMDPHT'               [-1.0000e+09]    [ 1.0000e+09]
%     'DAPE'                 [-1.0000e+09]    [ 1.0000e+09]
%     'LYCBC1'               [-1.0000e+09]    [ 1.0000e+09]
%     'RB15BPtcx'            [          0]    [ 1.0000e+09]
%     'GLCBRAN3'             [          0]    [ 1.0000e+09]
%     'DB4PS'                [          0]    [ 1.0000e+09]
%     'DXPRIi'               [          0]    [ 1.0000e+09]
%     'GTPCII'               [          0]    [ 1.0000e+09]
%     'RBFSa'                [          0]    [ 1.0000e+09]
%     'GLUTRS'               [          0]    [ 1.0000e+09]
%     'ALDD2y'               [-1.0000e+09]    [ 1.0000e+09]
%     'EHGLAT'               [-1.0000e+09]    [ 1.0000e+09]
%     'METAT'                [          0]    [ 1.0000e+09]
%     'DHORTS'               [-1.0000e+09]    [ 1.0000e+09]
%     'PDX5PS2'              [-1.0000e+09]    [ 1.0000e+09]
%     'ARGDC'                [          0]    [ 1.0000e+09]
%     'GAPDi_nadp'           [          0]    [ 1.0000e+09]
%     'GLXO3r'               [-1.0000e+09]    [ 1.0000e+09]
%     'PGCD'                 [-1.0000e+09]    [ 1.0000e+09]
%     'AIRC3'                [-1.0000e+09]    [ 1.0000e+09]
%     'UMPK'                 [-1.0000e+09]    [ 1.0000e+09]
%     'CBPS'                 [          0]    [ 1.0000e+09]
%     '3HAD180'              [-1.0000e+09]    [ 1.0000e+09]
%     'IMDHT'                [          0]    [ 1.0000e+09]
%     'RZ5PP'                [          0]    [ 1.0000e+09]
%     'RBFSb'                [          0]    [ 1.0000e+09]
%     'GLNabcpp'             [          0]    [ 1.0000e+09]
%     'NDPK8'                [-1.0000e+09]    [ 1.0000e+09]
%     'PC6YM'                [          0]    [ 1.0000e+09]
%     'DDPA'                 [          0]    [ 1.0000e+09]
%     'ACOTA'                [-1.0000e+09]    [ 1.0000e+09]
%     'FBP'                  [          0]    [ 1.0000e+09]
%     'MNabc_1'              [          0]    [ 1.0000e+09]
%     'NTD7'                 [          0]    [ 1.0000e+09]
%     'MPOMMM'               [          0]    [ 1.0000e+09]
%     'MTHFD'                [-1.0000e+09]    [ 1.0000e+09]
%     'PANTS'                [          0]    [ 1.0000e+09]
%     'TMPK'                 [          0]    [ 1.0000e+09]
%     'ASNS1'                [          0]    [ 1.0000e+09]
%     'AGPR'                 [-1.0000e+09]    [ 1.0000e+09]
%     'KARI_23dhmp'          [          0]    [ 1.0000e+09]
%     'IPMD'                 [          0]    [ 1.0000e+09]
%     '3PGtcx'               [          0]    [ 1.0000e+09]
%     'CDPMEK'               [          0]    [ 1.0000e+09]
%     'CITCIa'               [-1.0000e+09]    [ 1.0000e+09]
%     'SUCDum'               [-1.0000e+09]    [ 1.0000e+09]
%     'DVOCHR'               [          0]    [ 1.0000e+09]
%     'H2CO3_NAt_syn'        [-1.0000e+09]    [ 1.0000e+09]
%     'HEMEOS'               [-1.0000e+09]    [ 1.0000e+09]
%     'ALAD_L'               [-1.0000e+09]    [ 1.0000e+09]
%     'RPE'                  [-1.0000e+09]    [ 1.0000e+09]
%     'MPOMT'                [          0]    [ 1.0000e+09]
%     'NDHPQRum'             [          0]    [ 1.0000e+09]
%     'UAMAS'                [          0]    [ 1.0000e+09]
%     'CITCIb'               [-1.0000e+09]    [ 1.0000e+09]
%     'BPNT2'                [          0]    [ 1.0000e+09]
%     'BM_COFACTORS'         [          0]    [ 1.0000e+09]
%     'DCTPD2'               [          0]    [ 1.0000e+09]
%     'HSERTA'               [          0]    [ 1.0000e+09]
%     'NDPK1'                [-1.0000e+09]    [ 1.0000e+09]
%     'PGL'                  [          0]    [ 1.0000e+09]
%     'EAR160y'              [          0]    [ 1.0000e+09]
%     'MECDPDHf'             [          0]    [ 1.0000e+09]
%     'MTHFR3_1'             [          0]    [ 1.0000e+09]
%     '3HAD140'              [-1.0000e+09]    [ 1.0000e+09]
%     'FBA3'                 [-1.0000e+09]    [ 1.0000e+09]
%     'DAPNH4T'              [          0]    [ 1.0000e+09]
%     'MG2uabcpp'            [          0]    [ 1.0000e+09]
%     'HCO3E_1_cx'           [-1.0000e+09]    [ 1.0000e+09]
%     'ACODA'                [-1.0000e+09]    [ 1.0000e+09]
%     'GLU5K'                [          0]    [ 1.0000e+09]
%     'EAR100y'              [          0]    [ 1.0000e+09]
%     'PGM'                  [-1.0000e+09]    [ 1.0000e+09]
%     'ASPOb'                [          0]    [ 1.0000e+09]
%     'DM_h2_c'              [          0]    [ 1.0000e+09]
%     'ACS'                  [          0]    [ 1.0000e+09]
%     'PKETX'                [          0]    [ 1.0000e+09]
%     'AMPTASECG'            [          0]    [ 1.0000e+09]
%     'SHCHCS3'              [          0]    [ 1.0000e+09]
%     'ATPPRT'               [          0]    [ 1.0000e+09]
%     'NDH-1(4)um'           [          0]    [ 1.0000e+09]
%     'UAGCVT'               [          0]    [ 1.0000e+09]
%     'TDPGDH'               [          0]    [ 1.0000e+09]
%     'ADSL2r'               [-1.0000e+09]    [ 1.0000e+09]
%     'PRASCSi'              [-1.0000e+09]    [ 1.0000e+09]
%     'MG2tex'               [-1.0000e+09]    [ 1.0000e+09]
%     'HPROb'                [          0]    [ 1.0000e+09]
%     'NTPP2'                [          0]    [ 1.0000e+09]
%     'TRDR'                 [          0]    [ 1.0000e+09]
%     'PKETF'                [          0]    [ 1.0000e+09]
%     'NDPK6'                [-1.0000e+09]    [ 1.0000e+09]
%     'GLUPRT'               [          0]    [ 1.0000e+09]
%     'PTRCabcpp'            [          0]    [ 1.0000e+09]
%     'UPP3MT'               [          0]    [ 1.0000e+09]
%     'DHNCOAS'              [          0]    [ 1.0000e+09]
%     'MCOATA'               [          0]    [ 1.0000e+09]
%     'PMPK'                 [          0]    [ 1.0000e+09]
%     'HMBS'                 [          0]    [ 1.0000e+09]
%     'PGLYCP'               [          0]    [ 1.0000e+09]
%     'UAGAAT2'              [          0]    [ 1.0000e+09]
%     'HTHRPDH'              [          0]    [ 1.0000e+09]
%     'BCT1_syn'             [          0]    [ 1.0000e+09]
%     'IPDDI'                [-1.0000e+09]    [ 1.0000e+09]
%     'GLYALDDy'             [-1.0000e+09]    [ 1.0000e+09]
%     'CITMS'                [          0]    [ 1.0000e+09]
%     'IMPC'                 [-1.0000e+09]    [ 1.0000e+09]
%     'OMCDC'                [          0]    [ 1.0000e+09]
%     'Htcx'                 [-1.0000e+09]    [ 1.0000e+09]
%     'DHQTi'                [-1.0000e+09]    [ 1.0000e+09]
%     'SPODM'                [          0]    [ 1.0000e+09]
%     'MAN6PI'               [-1.0000e+09]    [ 1.0000e+09]
%     '3OAS120'              [          0]    [ 1.0000e+09]
%     'PGAMT'                [-1.0000e+09]    [ 1.0000e+09]
%     'ZDS'                  [          0]    [ 1.0000e+09]
%     'PSERT'                [-1.0000e+09]    [ 1.0000e+09]
%     'HISTP'                [          0]    [ 1.0000e+09]
%     'NNDPR'                [          0]    [ 1.0000e+09]
%     'ADSK'                 [          0]    [ 1.0000e+09]
%     'MECDPS'               [          0]    [ 1.0000e+09]
%     'CUabcpp'              [          0]    [ 1.0000e+09]
%     'ADCYRS'               [          0]    [ 1.0000e+09]
%     'RBPCcx'               [          0]    [ 1.0000e+09]
%     '3HAD40_1'             [-1.0000e+09]    [ 1.0000e+09]
%     'EAR180x'              [-1.0000e+09]    [ 1.0000e+09]
%     'GTHRDH'               [          0]    [ 1.0000e+09]
%     'PRAIi'                [          0]    [ 1.0000e+09]
%     'CYNTtabcpp'           [          0]    [ 1.0000e+09]
%     'TRSARyr'              [          0]    [ 1.0000e+09]
%     'PTPATi'               [          0]    [ 1.0000e+09]
%     'PC6AR'                [-1.0000e+09]    [ 1.0000e+09]
%     'Kabcpp'               [          0]    [ 1.0000e+09]
%     'ENO'                  [-1.0000e+09]    [ 1.0000e+09]
%     'TDPDRR'               [          0]    [ 1.0000e+09]
%     'PRFGS'                [          0]    [ 1.0000e+09]
%     'PC8XM'                [-1.0000e+09]    [ 1.0000e+09]
%     '3OAS60'               [          0]    [ 1.0000e+09]
%     'GMPS2'                [-1.0000e+09]    [ 1.0000e+09]
%     'RBFK'                 [          0]    [ 1.0000e+09]
%     'NTRIRfx'              [          0]    [ 1.0000e+09]
%     'GTHPi'                [          0]    [ 1.0000e+09]
%     'ARGSS'                [          0]    [ 1.0000e+09]
%     'SPTr'                 [-1.0000e+09]    [ 1.0000e+09]
%     'H2Otpp'               [-1.0000e+09]    [ 1.0000e+09]
%     'TDPDRE'               [          0]    [ 1.0000e+09]
%     'GTHOr'                [-1.0000e+09]    [ 1.0000e+09]
%     'SHK3Dr'               [-1.0000e+09]    [ 1.0000e+09]
%     'CYRDAR'               [-1.0000e+09]    [ 1.0000e+09]
%     'ORPT'                 [-1.0000e+09]    [ 1.0000e+09]
%     'GRTT'                 [          0]    [ 1.0000e+09]
%     'TRDRf'                [          0]    [ 1.0000e+09]
%     'BM_MEM_LIPIDS'        [          0]    [ 1.0000e+09]
%     'PRPPS'                [-1.0000e+09]    [ 1.0000e+09]
%     'KARA1i'               [          0]    [ 1.0000e+09]
%     'SPRMS'                [          0]    [ 1.0000e+09]
%     'FCLT'                 [          0]    [ 1.0000e+09]
%     'PPA'                  [          0]    [ 1.0000e+09]
%     'DHQS'                 [          0]    [ 1.0000e+09]
%     'ANPRT'                [          0]    [ 1.0000e+09]
%     'ADK1'                 [-1.0000e+09]    [ 1.0000e+09]
%     'UPP3S'                [          0]    [ 1.0000e+09]
%     'NDPK5'                [-1.0000e+09]    [ 1.0000e+09]
%     'NDHPQRcm'             [          0]    [ 1.0000e+09]
%     'DHNPA_1'              [          0]    [ 1.0000e+09]
%     'NDPK4'                [-1.0000e+09]    [ 1.0000e+09]
%     'RNDR4'                [          0]    [ 1.0000e+09]
%     'NADK'                 [          0]    [ 1.0000e+09]
%     '3OAR40_1'             [-1.0000e+09]    [ 1.0000e+09]
%     'TKT1'                 [-1.0000e+09]    [ 1.0000e+09]
%     'NO3abcpp'             [          0]    [ 1.0000e+09]
%     'FE3abcpp'             [          0]    [ 1.0000e+09]
%     'MOBDabcpp'            [          0]    [ 1.0000e+09]
%     'NPHBDC'               [          0]    [ 1.0000e+09]
%     'NPDPS'                [          0]    [ 1.0000e+09]
%     'NI2uabcpp'            [          0]    [ 1.0000e+09]
%     'HCO3tcx'              [          0]    [ 1.0000e+09]
%     'RNDR2'                [          0]    [ 1.0000e+09]
%     'KARI'                 [          0]    [ 1.0000e+09]
%     'EAR40y'               [          0]    [ 1.0000e+09]
%     'NADTRHD'              [          0]    [          0]
%     'DHNCOAT'              [          0]    [ 1.0000e+09]
%     'BM_PROTEIN'           [          0]    [ 1.0000e+09]
%     '3OAS100'              [          0]    [ 1.0000e+09]
%     'G1SAT'                [-1.0000e+09]    [ 1.0000e+09]
%     'ILETA'                [-1.0000e+09]    [ 1.0000e+09]
%     'PDS1'                 [          0]    [ 1.0000e+09]
%     'UAAGDS'               [          0]    [ 1.0000e+09]
%     'GLCDBRAN3'            [          0]    [ 1.0000e+09]
%     'HEX1'                 [          0]    [ 1.0000e+09]
%     'ATPSum'               [-1.0000e+09]    [ 1.0000e+09]
%     'CHPHYS'               [          0]    [ 1.0000e+09]
%     'BCAROHX'              [          0]    [ 1.0000e+09]
%     'GLYCLTDx'             [          0]    [ 1.0000e+09]
%     'PIuabcpp'             [          0]    [ 1.0000e+09]
%     'PC20M'                [          0]    [ 1.0000e+09]
%     'ADSS'                 [          0]    [ 1.0000e+09]
%     'BM_RNA'               [          0]    [ 1.0000e+09]
%     'DM_dialurate_c'       [          0]    [ 1.0000e+09]
%     'THRPD'                [          0]    [ 1.0000e+09]
%     'TMDS3'                [          0]    [ 1.0000e+09]
%     'DHFR'                 [          0]    [ 1.0000e+09]
%     'ACGS'                 [          0]    [ 1.0000e+09]
%     'VALTA'                [-1.0000e+09]    [ 1.0000e+09]
%     'AFAT'                 [          0]    [ 1.0000e+09]
%     'GLYOX_1'              [-1.0000e+09]    [ 1.0000e+09]
%     'EAR140y'              [          0]    [ 1.0000e+09]
%     'FRTT'                 [          0]    [ 1.0000e+09]
%     'CTPS2'                [          0]    [ 1.0000e+09]
%     'DESAT16a'             [-1.0000e+09]    [ 1.0000e+09]
%     'CO2tex'               [-1.0000e+09]    [ 1.0000e+09]
%     'GTHS'                 [          0]    [ 1.0000e+09]
%     'UAGDP'                [          0]    [ 1.0000e+09]
%     'DADK'                 [-1.0000e+09]    [ 1.0000e+09]
%     'MPOMC1'               [          0]    [ 1.0000e+09]
%     'Nat_Kpp'              [          0]    [ 1.0000e+09]
%     '3OAS180'              [          0]    [ 1.0000e+09]
%     'ARGDHpp'              [          0]    [ 1.0000e+09]
%     'EAR80y'               [          0]    [ 1.0000e+09]
%     'ERTHMMOR'             [          0]    [ 1.0000e+09]
%     'PDH'                  [          0]    [ 1.0000e+09]
%     'MPML'                 [          0]    [ 1.0000e+09]
%     'USHD2'                [          0]    [ 1.0000e+09]
%     'TPI'                  [-1.0000e+09]    [ 1.0000e+09]
%     'DHPPDA'               [          0]    [ 1.0000e+09]
%     'PRMICI'               [          0]    [ 1.0000e+09]
%     'CYTBD4um'             [          0]    [ 1.0000e+09]
%     'DM_co_c'              [          0]    [ 1.0000e+09]
%     'CAT'                  [          0]    [ 1.0000e+09]
%     'GLUR'                 [-1.0000e+09]    [ 1.0000e+09]
%     'ALAR'                 [-1.0000e+09]    [ 1.0000e+09]
%     'SULR'                 [          0]    [ 1.0000e+09]
%     'NAt3ipp'              [-1.0000e+09]    [ 1.0000e+09]
%     'ADCS'                 [          0]    [ 1.0000e+09]
%     'UGMDDS'               [          0]    [ 1.0000e+09]
%     'BM_CARB'              [          0]    [ 1.0000e+09]
%     'ICDHyr'               [          0]    [ 1.0000e+09]
%     'ACHBSb'               [          0]    [ 1.0000e+09]
%     'MTRI'                 [-1.0000e+09]    [ 1.0000e+09]
%     'SPMS'                 [          0]    [ 1.0000e+09]
%     'AHSERL2'              [          0]    [ 1.0000e+09]
%     'PEPC'                 [          0]    [ 1.0000e+09]
%     'PHETA1'               [-1.0000e+09]    [ 1.0000e+09]
%     'CHORM'                [-1.0000e+09]    [ 1.0000e+09]
%     'GAPD'                 [          0]    [ 1.0000e+09]
%     'PQH2tcm'              [          0]    [ 1.0000e+09]
%     'CPPPGO'               [          0]    [ 1.0000e+09]
%     'URIDK2r'              [-1.0000e+09]    [ 1.0000e+09]
%     'OCBT'                 [-1.0000e+09]    [ 1.0000e+09]
%     'E4PD'                 [          0]    [ 1.0000e+09]
%     'IMDHT_3c2hmp'         [          0]    [ 1.0000e+09]
%     'GLGC'                 [          0]    [ 1.0000e+09]
%     'PYK'                  [          0]    [ 1.0000e+09]
%     '3HAD120'              [-1.0000e+09]    [ 1.0000e+09]
%     '2PGLYCtcx'            [          0]    [ 1.0000e+09]
%     'MPOMOR'               [          0]    [ 1.0000e+09]
%     '3OAS160'              [          0]    [ 1.0000e+09]
%     'IG3PS'                [          0]    [ 1.0000e+09]
%     'DMPPS_syn'            [          0]    [ 1.0000e+09]
%     'NTRARf2'              [          0]    [ 1.0000e+09]
%     'G6PDA'                [          0]    [ 1.0000e+09]
%     'PFK'                  [          0]    [ 1.0000e+09]
%     'CA2t2pp'              [          0]    [ 1.0000e+09]
%     'DM_5drib_c'           [          0]    [ 1.0000e+09]
%     'RPI'                  [-1.0000e+09]    [ 1.0000e+09]
%     'FMNRy'                [          0]    [ 1.0000e+09]
%     'ANS2'                 [          0]    [ 1.0000e+09]
%     'GHMT2r'               [-1.0000e+09]    [ 1.0000e+09]
%     'BPNT'                 [          0]    [ 1.0000e+09]
%     'PSIIum'               [          0]    [     8.3514]
%     'CBFCum'               [          0]    [ 1.0000e+09]
%     'SK_amylose_c'         [-1.0000e+09]    [          0]
%     'SK_14glucan_c'        [          0]    [          0]
%     'SK_glycogen_c'        [          0]    [          0]
%     'EX_h2o_e'             [   -1000000]    [ 1.0000e+09]
%     'EX_o2_e'              [   -1000000]    [     0.8543]
%     'EX_co2_e'             [    -2.3861]    [ 1.0000e+09]
%     'EX_leu__L_e'          [          0]    [ 1.0000e+09]
%     'EX_cobalt2_e'         [    -0.0170]    [ 1.0000e+09]
%     'EX_zn2_e'             [    -0.0770]    [ 1.0000e+09]
%     'EX_so4_e'             [        -30]    [ 1.0000e+09]
%     'EX_spmd_e'            [          0]    [ 1.0000e+09]
%     'EX_ca2_e'             [        -24]    [ 1.0000e+09]
%     'EX_nh4_e'             [    -3.1000]    [ 1.0000e+09]
%     'EX_arg__L_e'          [          0]    [ 1.0000e+09]
%     'EX_gln__L_e'          [          0]    [ 1.0000e+09]
%     'EX_mn2_e'             [    -0.9000]    [ 1.0000e+09]
%     'EX_hco3_e'            [    -2.3861]    [ 1.0000e+09]
%     'EX_mg2_e'             [        -30]    [ 1.0000e+09]
%     'EX_ptrc_e'            [          0]    [ 1.0000e+09]
%     'EX_fe2_e'             [          0]    [ 1.0000e+09]
%     'EX_cu2_e'             [    -0.0300]    [ 1.0000e+09]
%     'EX_k_e'               [        -46]    [ 1.0000e+09]
%     'EX_no3_e'             [      -1760]    [ 1.0000e+09]
%     'EX_fe3_e'             [         -2]    [ 1.0000e+09]
%     'EX_mobd_e'            [    -0.1600]    [ 1.0000e+09]
%     'EX_ni2_e'             [          0]    [ 1.0000e+09]
%     'EX_na1_e'             [-1.7985e+03]    [ 1.0000e+09]
%     'EX_cynt_e'            [          0]    [ 1.0000e+09]
%     'EX_h_e'               [   -1000000]    [ 1.0000e+09]
%     'FE3tex'               [-1.0000e+09]    [ 1.0000e+09]
%     'FE2tex'               [-1.0000e+09]    [ 1.0000e+09]
%     'NI2tex'               [-1.0000e+09]    [ 1.0000e+09]
%     'MNtex'                [-1.0000e+09]    [ 1.0000e+09]
%     'COBALT2tex'           [-1.0000e+09]    [ 1.0000e+09]
%     'CU2tex'               [-1.0000e+09]    [ 1.0000e+09]
%     'Zn2tex'               [-1.0000e+09]    [ 1.0000e+09]
%     'SPMDtex'              [-1.0000e+09]    [ 1.0000e+09]
%     'LEUtex'               [-1.0000e+09]    [ 1.0000e+09]
%     'HCO3tex'              [-1.0000e+09]    [ 1.0000e+09]
%     'GLNtex'               [-1.0000e+09]    [ 1.0000e+09]
%     'CYNTtex'              [-1.0000e+09]    [ 1.0000e+09]
%     'ARGtex'               [-1.0000e+09]    [ 1.0000e+09]
%     'MOBDtex'              [-1.0000e+09]    [ 1.0000e+09]
%     'NH4tex'               [-1.0000e+09]    [ 1.0000e+09]
%     'SO4tex'               [-1.0000e+09]    [ 1.0000e+09]
%     'PTRCtex'              [-1.0000e+09]    [ 1.0000e+09]
%     'NO3tex'               [-1.0000e+09]    [ 1.0000e+09]
%     'NAtex'                [-1.0000e+09]    [ 1.0000e+09]
%     'CA2tex'               [-1.0000e+09]    [ 1.0000e+09]
%     'Ktex'                 [-1.0000e+09]    [ 1.0000e+09]
%     'CO2tpp'               [-1.0000e+09]    [ 1.0000e+09]
%     'EX_pi_e'              [   -20.9437]    [ 1.0000e+09]
%     'PItex'                [-1.0000e+09]    [ 1.0000e+09]
%     'MDRPD'                [          0]    [ 1.0000e+09]
%     'ENOPH'                [          0]    [ 1.0000e+09]
%     'ARD'                  [          0]    [ 1.0000e+09]
%     'UNK3'                 [          0]    [ 1.0000e+09]
%     'PHYPQOX'              [          0]    [ 1.0000e+09]
%     'ZISO'                 [          0]    [ 1.0000e+09]
%     'ZCARDS'               [          0]    [ 1.0000e+09]
%     'PLYCOI'               [          0]    [ 1.0000e+09]
%     'CHLADMT'              [          0]    [ 1.0000e+09]
%     'PHEOASE'              [          0]    [ 1.0000e+09]
%     'PHEOX'                [          0]    [ 1.0000e+09]
%     'PHYTK'                [          0]    [ 1.0000e+09]
%     'TRNFE'                [-1.0000e+09]    [ 1.0000e+09]
%     'PTHPS'                [          0]    [ 1.0000e+09]
%     'SPR'                  [          0]    [ 1.0000e+09]
%     'THBTGT'               [          0]    [ 1.0000e+09]
%     'NADDP'                [          0]    [ 1.0000e+09]
%     'CYSDS'                [          0]    [ 1.0000e+09]
%     'THISAT'               [          0]    [ 1.0000e+09]
%     'THII'                 [          0]    [ 1.0000e+09]
%     'GLYCOX1'              [          0]    [ 1.0000e+09]
%     'GLYCOX2'              [          0]    [ 1.0000e+09]
%     'DXYTST'               [          0]    [ 1.0000e+09]
%     'THZT'                 [          0]    [ 1.0000e+09]
%     'SHS1'                 [          0]    [ 1.0000e+09]
%     'MALCOAMT'             [          0]    [ 1.0000e+09]
%     'OGMEACPS'             [          0]    [ 1.0000e+09]
%     'OGMEACPR'             [          0]    [ 1.0000e+09]
%     'OGMEACPD'             [          0]    [ 1.0000e+09]
%     'EGMEACPR'             [          0]    [ 1.0000e+09]
%     'OPMEACPS'             [          0]    [ 1.0000e+09]
%     'OPMEACPR'             [          0]    [ 1.0000e+09]
%     'OPMEACPD'             [          0]    [ 1.0000e+09]
%     'EPMEACPR'             [          0]    [ 1.0000e+09]
%     'PMEACPE'              [          0]    [ 1.0000e+09]
%     'AOXSr2'               [-1.0000e+09]    [ 1.0000e+09]
%     'AMAOTr'               [-1.0000e+09]    [ 1.0000e+09]
%     'DBTS'                 [          0]    [ 1.0000e+09]
%     'BTS6'                 [          0]    [ 1.0000e+09]
%     'BACCL'                [          0]    [ 1.0000e+09]
%     'BTNPL2'               [          0]    [ 1.0000e+09]
%     'LIPOCT'               [          0]    [ 1.0000e+09]
%     'LIPOS2'               [          0]    [ 1.0000e+09]
%     'LIPATPT'              [          0]    [ 1.0000e+09]
%     'LIPAMPL'              [          0]    [ 1.0000e+09]
%     'MEOHtpp'              [-1.0000e+09]    [ 1.0000e+09]
%     'MEOHtex'              [-1.0000e+09]    [ 1.0000e+09]
%     'DM_amob_c'            [          0]    [ 1.0000e+09]
%     'AGTi'                 [          0]    [ 1.0000e+09]
%     'ADNK1'                [          0]    [ 1.0000e+09]
%     'CPH4S'                [          0]    [ 1.0000e+09]
%     'CDGS'                 [          0]    [ 1.0000e+09]
%     'CCGS'                 [          0]    [ 1.0000e+09]
%     'CDGR'                 [          0]    [ 1.0000e+09]
%     'QUERT'                [          0]    [ 1.0000e+09]
%     'SAMTRI'               [          0]    [ 1.0000e+09]
%     'EPXQR'                [          0]    [ 1.0000e+09]
%     'UPPRT'                [          0]    [ 1.0000e+09]
%     'UDPGD'                [          0]    [ 1.0000e+09]
%     'UDPGLDC'              [          0]    [ 1.0000e+09]
%     'GMAND'                [          0]    [ 1.0000e+09]
%     'GFUCS'                [          0]    [ 1.0000e+09]
%     'ALCD19'               [-1.0000e+09]    [ 1.0000e+09]
%     'CDPGLC46DH'           [          0]    [ 1.0000e+09]
%     'SPP'                  [          0]    [ 1.0000e+09]
%     'NDH-1(2)um'           [          0]    [          0]
%     'NDH-1(3)um'           [          0]    [          0]
%     'KAS15'                [          0]    [ 1.0000e+09]
%     'AACPS6'               [          0]    [ 1.0000e+09]
%     'ALDR18'               [          0]    [ 1.0000e+09]
%     'ALDDC17'              [          0]    [ 1.0000e+09]
%     'G3PAT160'             [          0]    [ 1.0000e+09]
%     'G3PAT161'             [          0]    [ 1.0000e+09]
%     'G3PAT1819Z'           [          0]    [ 1.0000e+09]
%     'AGPAT160'             [          0]    [ 1.0000e+09]
%     'AGPATACP_HDE_PALM'    [          0]    [ 1.0000e+09]
%     'AGPAT161'             [          0]    [ 1.0000e+09]
%     'AGPATACP_OLE_HDE'     [          0]    [ 1.0000e+09]
%     'AGPATACP_OLE_PALM'    [          0]    [ 1.0000e+09]
%     'PAPA160'              [          0]    [ 1.0000e+09]
%     'PAPA_HDE_PALM'        [          0]    [ 1.0000e+09]
%     'PAPA161'              [          0]    [ 1.0000e+09]
%     'PAPA_OLE_HDE'         [          0]    [ 1.0000e+09]
%     'PAPA_OLE_PALM'        [          0]    [ 1.0000e+09]
%     'SQDGS_PALM_PALM'      [          0]    [ 1.0000e+09]
%     'SQDGS_HDE_PALM'       [          0]    [ 1.0000e+09]
%     'DGDGS_HDE_PALM'       [          0]    [ 1.0000e+09]
%     'DGDGS_HDE_HDE'        [          0]    [ 1.0000e+09]
%     'DGDGS_OLE_HDE'        [          0]    [ 1.0000e+09]
%     'CDPDAGS_OLE_PALM'     [          0]    [ 1.0000e+09]
%     'PGPS_OLE_PALM'        [          0]    [ 1.0000e+09]
%     'PGPP_OLE_PALM'        [          0]    [ 1.0000e+09]
%     'DAGK160'              [          0]    [ 1.0000e+09]
%     'DAGK_HDE_PALM'        [          0]    [ 1.0000e+09]
%     'DAGK161'              [          0]    [ 1.0000e+09]
%     'DAGK_OLE_HDE'         [          0]    [ 1.0000e+09]
%     'DAGK_OLE_PALM'        [          0]    [ 1.0000e+09]
%     'GLUDGS_HDE_PALM'      [          0]    [ 1.0000e+09]
%     'GLUDGE_HDE_PALM'      [          0]    [ 1.0000e+09]
%     'GLUDGS_HDE_HDE'       [          0]    [ 1.0000e+09]
%     'GLUDGE_HDE_HDE'       [          0]    [ 1.0000e+09]
%     'GLUDGS_OLE_HDE'       [          0]    [ 1.0000e+09]
%     'GLUDGE_OLE_HDE'       [          0]    [ 1.0000e+09]
%     'GLUDGS_OLE_PALM'      [          0]    [ 1.0000e+09]
%     'GLUDGE_OLE_PALM'      [          0]    [ 1.0000e+09]
%     'DGDGS_OLE_PALM'       [          0]    [ 1.0000e+09]
%     'H2Otcx'               [-1.0000e+09]    [ 1.0000e+09]
%     'GLNTRS'               [          0]    [ 1.0000e+09]
%     'TYRTRS'               [          0]    [ 1.0000e+09]
%     'METTRS'               [          0]    [ 1.0000e+09]
%     'SERTRS'               [          0]    [ 1.0000e+09]
%     'GLYTRS'               [          0]    [ 1.0000e+09]
%     'PROTRS'               [          0]    [ 1.0000e+09]
%     'CYSTRS'               [          0]    [ 1.0000e+09]
%     'ARGTRS'               [          0]    [ 1.0000e+09]
%     'TRPTRS'               [          0]    [ 1.0000e+09]
%     'PHETRS'               [          0]    [ 1.0000e+09]
%     'HISTRS'               [          0]    [ 1.0000e+09]
%     'ASNTRS'               [          0]    [ 1.0000e+09]
%     'ASPTRS'               [          0]    [ 1.0000e+09]
%     'THRTRS'               [          0]    [ 1.0000e+09]
%     'LEUTRS'               [          0]    [ 1.0000e+09]
%     'ILETRS'               [          0]    [ 1.0000e+09]
%     'LYSTRS'               [          0]    [ 1.0000e+09]
%     'ALATRS'               [          0]    [ 1.0000e+09]
%     'VALTRS'               [          0]    [ 1.0000e+09]
%     'FMETTRS'              [          0]    [ 1.0000e+09]
%     'EX_photon410_e'       [    -4.4397]    [    -4.4393]
%     'EX_photon430_e'       [   -12.3754]    [   -12.3742]
%     'EX_photon450_e'       [    -5.6760]    [    -5.6754]
%     'EX_photon470_e'       [    -4.8560]    [    -4.8555]
%     'EX_photon490_e'       [    -7.7388]    [    -7.7380]
%     'EX_photon510_e'       [    -1.9325]    [    -1.9323]
%     'EX_photon530_e'       [    -1.9501]    [    -1.9499]
%     'EX_photon550_e'       [    -7.5922]    [    -7.5915]
%     'EX_photon570_e'       [    -2.8973]    [    -2.8970]
%     'EX_photon590_e'       [    -6.1517]    [    -6.1511]
%     'EX_photon610_e'       [   -12.3441]    [   -12.3429]
%     'EX_photon630_e'       [    -5.8419]    [    -5.8414]
%     'EX_photon650_e'       [    -1.6753]    [    -1.6751]
%     'EX_photon670_e'       [    -1.2516]    [    -1.2515]
%     'EX_photon690_e'       [    -0.7279]    [    -0.7279]
%     'ZXANHX'               [          0]    [ 1.0000e+09]
%     'CXANHX'               [          0]    [ 1.0000e+09]
%     'PHOA410um'            [          0]    [ 1.0000e+09]
%     'PHOA430um'            [          0]    [ 1.0000e+09]
%     'PHOA450um'            [          0]    [ 1.0000e+09]
%     'PHOA470um'            [          0]    [ 1.0000e+09]
%     'PHOA490um'            [          0]    [ 1.0000e+09]
%     'PHOA510um'            [          0]    [ 1.0000e+09]
%     'PHOA530um'            [          0]    [ 1.0000e+09]
%     'PHOA550um'            [          0]    [ 1.0000e+09]
%     'PHOA570um'            [          0]    [ 1.0000e+09]
%     'PHOA590um'            [          0]    [ 1.0000e+09]
%     'PHOA610um'            [          0]    [ 1.0000e+09]
%     'PHOA630um'            [          0]    [ 1.0000e+09]
%     'PHOA650um'            [          0]    [ 1.0000e+09]
%     'PHOA670um'            [          0]    [ 1.0000e+09]
%     'PHOA690um'            [          0]    [ 1.0000e+09]
%     'DM_pho_loss_c'        [          0]    [ 1.0000e+09]
%     'ETCHLAS'              [          0]    [ 1.0000e+09]
%     'ETBCARO'              [          0]    [ 1.0000e+09]
%     'ETCPC'                [          0]    [ 1.0000e+09]
%     'STACPSI'              [          0]    [ 1.0000e+09]
%     'A5PISO'               [-1.0000e+09]    [ 1.0000e+09]
%     'KDOPS'                [          0]    [ 1.0000e+09]
%     'KDOPP'                [          0]    [ 1.0000e+09]
%     'KDOCT2'               [          0]    [ 1.0000e+09]
%     'MOAT'                 [          0]    [ 1.0000e+09]
%     'UAG2E'                [-1.0000e+09]    [ 1.0000e+09]
%     'ACGAMT'               [          0]    [ 1.0000e+09]
%     'ACMAMT'               [          0]    [ 1.0000e+09]
%     'ICLIPAS'              [          0]    [ 1.0000e+09]
%     'ICLIPAabcpp'          [          0]    [ 1.0000e+09]
%     'OANTS'                [          0]    [ 1.0000e+09]
%     'OANTIabcpp'           [          0]    [ 1.0000e+09]
%     'OANTILpp'             [          0]    [ 1.0000e+09]
%     'COLIPAabcex'          [          0]    [ 1.0000e+09]
%     'MPTG'                 [          0]    [ 1.0000e+09]
%     'MPTG2'                [          0]    [ 1.0000e+09]
%     'MCTP2App'             [          0]    [ 1.0000e+09]
%     'MCTP1App'             [          0]    [ 1.0000e+09]
%     'MCTP1Bpp'             [          0]    [ 1.0000e+09]
%     'MDDCP1pp'             [          0]    [ 1.0000e+09]
%     'MDDCP2pp'             [          0]    [ 1.0000e+09]
%     'MDDCP3pp'             [          0]    [ 1.0000e+09]
%     'MDDCP4pp'             [          0]    [ 1.0000e+09]
%     'MDDCP5pp'             [          0]    [ 1.0000e+09]
%     'MDDEP1pp'             [          0]    [ 1.0000e+09]
%     'MDDEP2pp'             [          0]    [ 1.0000e+09]
%     'MDDEP3pp'             [          0]    [ 1.0000e+09]
%     'MDDEP4pp'             [          0]    [ 1.0000e+09]
%     'MLDCP1App'            [          0]    [ 1.0000e+09]
%     'MLDCP1Bpp'            [          0]    [ 1.0000e+09]
%     'MLDCP2App'            [          0]    [ 1.0000e+09]
%     'MLDCP2Bpp'            [          0]    [ 1.0000e+09]
%     'MLTGY1pp'             [          0]    [ 1.0000e+09]
%     'MLTGY2pp'             [          0]    [ 1.0000e+09]
%     'MLTGY3pp'             [          0]    [ 1.0000e+09]
%     'MLTGY4pp'             [          0]    [ 1.0000e+09]
%     'AGM4PA'               [          0]    [ 1.0000e+09]
%     'AGM4PApp'             [          0]    [ 1.0000e+09]
%     'AGM4PCP'              [          0]    [ 1.0000e+09]
%     'AGM4PH'               [          0]    [ 1.0000e+09]
%     'AGM3PApp'             [          0]    [ 1.0000e+09]
%     'AGMH'                 [          0]    [ 1.0000e+09]
%     'AGM3PH'               [          0]    [ 1.0000e+09]
%     'AM4PCP'               [          0]    [ 1.0000e+09]
%     '4PCP'                 [          0]    [ 1.0000e+09]
%     'AM3PA'                [          0]    [ 1.0000e+09]
%     'AM4PA'                [          0]    [ 1.0000e+09]
%     'LADGMDH'              [          0]    [ 1.0000e+09]
%     'UM4PL'                [          0]    [ 1.0000e+09]
%     'ALAGLUE'              [-1.0000e+09]    [ 1.0000e+09]
%     'UM3PL'                [          0]    [ 1.0000e+09]
%     'UM4PCP'               [          0]    [ 1.0000e+09]
%     'LALGP'                [          0]    [ 1.0000e+09]
%     'AGM4Pt2pp'            [          0]    [ 1.0000e+09]
%     'AGMt2pp'              [          0]    [ 1.0000e+09]
%     '4PEPTabcpp'           [          0]    [ 1.0000e+09]
%     'UAGPT3'               [          0]    [ 1.0000e+09]
%     'UDCPDP'               [          0]    [ 1.0000e+09]
%     'PAPPT3'               [          0]    [ 1.0000e+09]
%     'ALAALAD'              [          0]    [ 1.0000e+09]
%     'DALAabcpp'            [          0]    [ 1.0000e+09]
%     'ALAALAabcpp'          [          0]    [ 1.0000e+09]
%     '3PEPTabcpp'           [          0]    [ 1.0000e+09]
%     'PCHLDA430'            [          0]    [ 1.0000e+09]
%     'PCHLDA650'            [          0]    [ 1.0000e+09]
%     'EX_meoh_e'            [          0]    [ 1.0000e+09]
%     'PFOR'                 [          0]    [ 1.0000e+09]
%     'NO2tabcpp'            [          0]    [ 1.0000e+09]
%     'NO2tex'               [-1.0000e+09]    [ 1.0000e+09]
%     'Htabcpp'              [          0]    [ 1.0000e+09]
%     'ETAPCPSII'            [          0]    [ 1.0000e+09]
%     'PSICSum'              [          0]    [ 1.0000e+09]
%     'PSIICSum'             [          0]    [ 1.0000e+09]
%     'STCHLPSIum'           [          0]    [ 1.0000e+09]
%     'DEXZEAX'              [          0]    [ 1.0000e+09]
%     'CELLSYN'              [          0]    [ 1.0000e+09]
%     'ADPGDP'               [          0]    [ 1.0000e+09]
%     'ALCD1'                [          0]    [ 1.0000e+09]
%     'FALGTHLs'             [          0]    [ 1.0000e+09]
%     'FALDH2'               [          0]    [ 1.0000e+09]
%     'SFGTHi'               [          0]    [ 1.0000e+09]
%     'GGCLUT2'              [          0]    [ 1.0000e+09]
%     'OPAH'                 [          0]    [ 1.0000e+09]
%     'ACGAMK'               [          0]    [ 1.0000e+09]
%     'AMANAPEr'             [-1.0000e+09]    [ 1.0000e+09]
%     'AGDC'                 [          0]    [ 1.0000e+09]
%     'ANHMK'                [          0]    [ 1.0000e+09]
%     'ACM6PH'               [          0]    [ 1.0000e+09]
%     'SUCR'                 [          0]    [ 1.0000e+09]
%     'CLt3_1pp'             [          0]    [ 1.0000e+09]
%     'Cltex'                [-1.0000e+09]    [ 1.0000e+09]
%     'EX_cl_e'              [          0]    [ 1.0000e+09]
%     'Ktu'                  [-1.0000e+09]    [ 1.0000e+09]
%     'FDH6'                 [          0]    [ 1.0000e+09]
%     'DM_fum_c'             [          0]    [ 1.0000e+09]
%     'DM_succ_c'            [          0]    [ 1.0000e+09]
%     'DM_akg_c'             [          0]    [ 1.0000e+09]
%     'NGAM_D1um'            [          0]    [ 1.0000e+09]
%     'PSICRum'              [          0]    [ 1.0000e+09]
%     'PSIICRum'             [          0]    [ 1.0000e+09]
%     'DM_ac_c'              [          0]    [ 1.0000e+09]
%     'DM_lac__D_c'          [          0]    [ 1.0000e+09]
%     'ASPO5'                [          0]    [ 1.0000e+09]
%     'MNHNAtpp'             [          0]    [ 1.0000e+09]
%     'PCXHtpp'              [          0]    [ 1.0000e+09]
%     'NGAM'                 [     0.0847]    [ 1.0000e+09]
%     'DM_pkcc'              [          0]    [ 1.0000e+09]

% %% [markdown]
% ### Next,

% %% [markdown]
% <!--NAVIGATION-->
% < [Original Simulation published in Broddrick et al 2016 PNAS](Original-Simulation-Broddrick-2016-PNAS.ipynb)>
