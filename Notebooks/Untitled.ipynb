# %%
# Importing intrinsic libraries:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statannot import add_stat_annotation

# %%
# Loading Pandas DataFrame:
df = pd.read_csv("Datasets/Data1.csv", encoding="windows-1252")

# %%
df
# Out:
#              strain  day condition  percent-mutant
# 0   synpcc7942_0863    0       LDC        0.560000
# 1   synpcc7942_0863    0       LDC        0.500000
# 2   synpcc7942_0863    0       LDC        0.420000
# 3   synpcc7942_0863    0       LDC        0.460000
# 4   synpcc7942_0863    2       LDC        0.650000
# 5   synpcc7942_0863    2       LDC        0.570000
# 6   synpcc7942_0863    2       LDC        0.890000
# 7   synpcc7942_0863    2       LDC        0.740000
# 8   synpcc7942_0863    6       LDC        0.990000
# 9   synpcc7942_0863    6       LDC        0.940000
# 10  synpcc7942_0863    6       LDC        0.990000
# 11  synpcc7942_0863    6       LDC        1.000000
# 12  synpcc7942_0644    0       LDC        0.491935
# 13  synpcc7942_0644    0       LDC        0.519608
# 14  synpcc7942_0644    0       LDC        0.491803
# 15  synpcc7942_0644    2       LDC        0.740741
# 16  synpcc7942_0644    2       LDC        0.617647
# ...

# %%
plot2 = sns.swarmplot(x="day", y="percent-mutant", hue = "strain",dodge=True, 
              data=df, palette=sns.color_palette(['black', 'black']))
plot1 = sns.boxplot(x="day", y="percent-mutant", hue = "strain", data=df, 
                    palette=sns.color_palette(['grey', 'white']))

# remove legend from axis 'ax'
plot2.legend_.remove()

# %%
# Loading Pandas DataFrame:
df = pd.read_csv("Datasets/Data1.csv", encoding="windows-1252")

# Set order you want to plot 
x = "strain"
y = "percent-mutant"
order=[0, 2, 6]

# make plots

swarmplot1 = sns.swarmplot(data=df, x=x, y=y, hue = "day", dodge=True, 
               palette=sns.color_palette(['black', 'red', 'blue']), hue_order=order)

boxplot1 = sns.boxplot(data=df, x=x, y=y, hue = "day",
                       palette=sns.color_palette(['grey', 'white']), hue_order=order)
# Fix the legand
# Get the handles and labels. 
handles, labels = boxplot1.get_legend_handles_labels()
# When creating the legend, only use the first two elements to effectively remove the last two.
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statannot import add_stat_annotation

sns.set(style="whitegrid")
df = pd.read_csv("Datasets/Data1.csv", encoding="windows-1252")

# Set order you want to plot 
x = "strain"
y = "percent-mutant"
hue = "day"
order=[0, 2, 6]

ax = sns.boxplot(data=df, x=x, y=y, hue=hue)
stat1 = add_stat_annotation(ax, data=df, x=x, y=y, hue=hue,
                    boxPairList=[(("synpcc7942_0863", 0), ("synpcc7942_0863", 2)),
                                 (("synpcc7942_0863", 2), ("synpcc7942_0863", 6)),
                                 (("synpcc7942_0863", 0), ("synpcc7942_0863", 6)),
                                ],
                    test='Mann-Whitney', textFormat='star', loc='outside', verbose=2)

stat2 = add_stat_annotation(ax, data=df, x=x, y=y, hue=hue,
                    boxPairList=[(("synpcc7942_0644", 0), ("synpcc7942_0644", 2)),
                                 (("synpcc7942_0644", 2), ("synpcc7942_0644", 6)),
                                 (("synpcc7942_0644", 0), ("synpcc7942_0644", 6))
                                ],
                    test='Mann-Whitney', textFormat='star', loc='outside', verbose=2)

plt.legend(loc='upper left', bbox_to_anchor=(1.03, 1))
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# synpcc7942_0863_0 v.s. synpcc7942_0863_2: MWW RankSum two-sided P_val=3.038e-02 U_stat=0.000e+00
# synpcc7942_0863_2 v.s. synpcc7942_0863_6: MWW RankSum two-sided P_val=2.940e-02 U_stat=0.000e+00
# synpcc7942_0863_0 v.s. synpcc7942_0863_6: MWW RankSum two-sided P_val=2.940e-02 U_stat=0.000e+00
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# synpcc7942_0644_0 v.s. synpcc7942_0644_2: MWW RankSum two-sided P_val=6.625e-01 U_stat=3.000e+00
# synpcc7942_0644_2 v.s. synpcc7942_0644_6: MWW RankSum two-sided P_val=6.625e-01 U_stat=3.000e+00
# synpcc7942_0644_0 v.s. synpcc7942_0644_6: MWW RankSum two-sided P_val=6.625e-01 U_stat=3.000e+00

# %%
plt.xticks()
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text xticklabel objects>)

# %%
# Loading built-in Tips dataset:
tips = sns.load_dataset("tips")
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.boxplot(x="day", y="total_bill", data=tips)

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)

# %%
sns.swarmplot(x="day", y="total_bill", data=tips, color = "black" )
sns.boxplot(x="day", y="total_bill", data=tips)

# %%
order = ['Sat', 'Sun', 'Fri', 'Thur']
swarmplot1 = sns.swarmplot(x="day", y="total_bill", data=tips, color = "black", order=order )
boxplot1 = sns.boxplot(x="day", y="total_bill", data=tips, order=order)

# add statistical annotation between Fri and Thur
Fri, Thur = 2, 3   # columns 'Sat' and 'Sun' (first column: 0, see plt.xticks())
y, h, col = tips['total_bill'].max() + 2, 2, 'k'
plt.plot([Fri, Fri, Thur, Thur], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((Fri+Thur)*.5, y+h, "***", ha='center', va='bottom', color=col)


# add statistical annotation between Sat and Fri
Sat, Fri = 0, 2   # columns 'Sat' and 'Sun' (first column: 0, see plt.xticks())
y, h, col = tips['total_bill'].max() + 4, 4, 'k'
plt.plot([Sat, Sat, Fri, Fri], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((Sat+Thur)*.5, y+h, "***", ha='center', va='bottom', color=col)


plt.show()

# %%
from statannot import add_stat_annotation

# %%
sns.set(style="whitegrid")
df = sns.load_dataset("tips")

x = "day"
y = "total_bill"
order = ['Sun', 'Thur', 'Fri', 'Sat']
ax = sns.boxplot(data=df, x=x, y=y, order=order)
add_stat_annotation(ax, data=df, x=x, y=y, order=order,
                    boxPairList=[("Thur", "Fri"), ("Thur", "Sat"), ("Fri", "Sun")],
                    test='Mann-Whitney', textFormat='star', loc='inside', verbose=2)
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Thur v.s. Fri: MWW RankSum two-sided P_val=6.477e-01 U_stat=6.305e+02
# Thur v.s. Sat: MWW RankSum two-sided P_val=4.690e-02 U_stat=2.180e+03
# Fri v.s. Sun: MWW RankSum two-sided P_val=2.680e-02 U_stat=4.835e+02

# %%
# Importing intrinsic libraries:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statannot import add_stat_annotation

# Loading built-in Tips dataset:
tips = sns.load_dataset("tips")
tips.head(5)

order = ['Sat', 'Thur', 'Fri', 'Sun']
swarmplot1 = sns.swarmplot(x="day", y="total_bill", data=tips, color = "black", order=order )
boxplot1 = sns.boxplot(x="day", y="total_bill", data=tips, order=order)

add_stat_annotation(boxplot1, data=tips, x="day", y="total_bill", order=order,
                    boxPairList=[("Thur", "Fri"), ("Thur", "Sat"), ("Fri", "Sun")],
                    test='Mann-Whitney', textFormat='star', loc='inside', verbose=2)
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Thur v.s. Fri: MWW RankSum two-sided P_val=6.477e-01 U_stat=6.305e+02
# Thur v.s. Sat: MWW RankSum two-sided P_val=4.690e-02 U_stat=2.180e+03
# Fri v.s. Sun: MWW RankSum two-sided P_val=2.680e-02 U_stat=4.835e+02

# %%
# Importing intrinsic libraries:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statannot import add_stat_annotation

# Loading built-in Tips dataset:
tips = sns.load_dataset("tips")
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
order2 = ['Sat', 'Thur', 'Fri', 'Sun']
swarmplot2 = sns.swarmplot(x="day", y="total_bill", data=tips, color = "black", order=order2 )
boxplot2 = sns.boxplot(x="day", y="total_bill", data=tips, order=order2)

add_stat_annotation(boxplot2, data=tips, x="day", y="total_bill", hue=hue,
                    boxPairList=[(("Thur", "No"), ("Fri", "No")),
                                 (("Sat", "Yes"), ("Sat", "No")),
                                 (("Sun", "No"), ("Thur", "Yes"))
                                ],
                    test='t-test_ind', textFormat='full', loc='inside', verbose=2)
#
plt.legend(loc='upper left', bbox_to_anchor=(1.03, 1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-2a002364cc65> in <module>
#       8                                  (("Sun", "No"), ("Thur", "Yes"))
#       9                                 ],
# ---> 10                     test='t-test_ind', textFormat='full', loc='inside', verbose=2)
#      11 #
#      12 plt.legend(loc='upper left', bbox_to_anchor=(1.03, 1))
#
# ~/anaconda3/envs/Testing/lib/python3.7/site-packages/statannot-0.1.0-py3.7.egg/statannot/statannot.py in add_stat_annotation(ax, data, x, y, hue, order, hue_order, boxPairList, test, textFormat, loc, pvalueThresholds, useFixedOffset, lineYOffsetToBoxAxesCoord, lineYOffsetAxesCoord, lineHeightAxesCoord, textYOffsetPoints, color, linewidth, fontsize, verbose)
#     255             yStack.append(yTopAnnot)
#     256         else:
# ...

# %%
tips = sns.load_dataset("tips")
sns.boxplot(x="day", y="total_bill", data=tips, palette="PRGn")

# statistical annotation
x1, x2 = 2, 3   # columns 'Sat' and 'Sun' (first column: 0, see plt.xticks())
y, h, col = tips['total_bill'].max() + 2, 2, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)

plt.show()

# %%
#######################

import matplotlib.pyplot as plt
import seaborn as sns
from statannot import add_stat_annotation

sns.set(style="whitegrid")
df = sns.load_dataset("tips")

x = "day"
y = "total_bill"
hue = "smoker"
ax = sns.boxplot(data=df, x=x, y=y, hue=hue)
add_stat_annotation(ax, data=df, x=x, y=y, hue=hue,
                    boxPairList=[(("Thur", "No"), ("Fri", "No")),
                                 (("Sat", "Yes"), ("Sat", "No")),
                                 (("Sun", "No"), ("Thur", "Yes"))
                                ],
                    test='t-test_ind', textFormat='full', loc='inside', verbose=2)
plt.legend(loc='upper left', bbox_to_anchor=(1.03, 1))
# Out:
# Thur_No v.s. Fri_No: t-test independent samples, P_val=7.425e-01 stat=-3.305e-01
# Sat_Yes v.s. Sat_No: t-test independent samples, P_val=4.304e-01 stat=7.922e-01
# Sun_No v.s. Thur_Yes: t-test independent samples, P_val=5.623e-01 stat=5.822e-01

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...
